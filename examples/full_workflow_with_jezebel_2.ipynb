# %% [markdown]
# We continue our demonstration of the full uncertainty quantification workflow with Jezebel. Here we perform the setup needed to run OpenMC with the perturbed cross sections

# %%
#Import modules
import WINDIGO
import os
from pathlib import Path
import openmc

# %%
#Save the paths to the perturbed cross section libraries from the previous example
pu239_direct_perturbation_ace_files = ('/mnt/c/Users/jacob/frendy_20241030/Pu239_DirectPerturbationACEFiles_ReactionMT_18')
pu239_random_sampling_ace_files = ('/mnt/c/Users/jacob/frendy_20241030/Pu239_RandomSamplingACEFiles_ReactionMT_18')

# %% [markdown]
# To utilize our perturbed cross sections, we need to first reformat them into the OpenMC-compatible .h5 format, and then construct custom cross_sections.xml files using the perturbed files. WINDIGO has a function that interfaces with OpenMC to perform both of these functions. To do this, we need knowledge of the specific isotopes and thermal scattering law data that will remain unperturbed within our model of interest. For Jezebel, we will neglect thermal scattering data.

# %% [markdown]
# The specific model for Jezebel is taken from a publically available GitHub repository from MIT's Computation Reactor Physics Group: https://github.com/mit-crpg/benchmarks/blob/master/icsbep/pu-met-fast-001/mcnp/input

# %%
#Set the list of nuclides whose data will remain unperturbed
unperturbed_nuclides = ['Pu240', 'Pu241', 'Ga69', 'Ga71']

#Create the perturbed cross_sections.xml files for the direct perturbation ACE files
direct_perturbation_models_directory = WINDIGO.build_perturbed_cross_sections_libraries(
                                       unperturbed_nuclide_list = unperturbed_nuclides,
                                       neutron_sublibrary_path = '/mnt/c/Users/jacob/endfb80/endfb-viii.0-hdf5/neutron',
                                       perturbed_ACE_folder_path = pu239_direct_perturbation_ace_files,
                                       perturbed_nuclide = 'Pu239',
                                       model_name='Jezebel',
                                       perturbation_type='Direct'
)

#Create the perturbed cross_sections.xml files for the random sampling ACE files
random_sampling_models_directory = WINDIGO.build_perturbed_cross_sections_libraries(
                                   unperturbed_nuclide_list = unperturbed_nuclides,
                                   neutron_sublibrary_path = '/mnt/c/Users/jacob/endfb80/endfb-viii.0-hdf5/neutron',
                                   perturbed_ACE_folder_path = pu239_random_sampling_ace_files,
                                   perturbed_nuclide = 'Pu239',
                                   model_name='Jezebel',
                                   perturbation_type='Random'
)
# Out:
# No thermal scattering data will be included.
# All perturbed cross_sections.xml files created. The folders containing them are located in: Jezebel_Pu239_DirectPerturbedModels
# No thermal scattering data will be included.
# All perturbed cross_sections.xml files created. The folders containing them are located in: Jezebel_Pu239_RandomPerturbedModels

# %% [markdown]
# When now have a set of folders with perturbed cross_sections.xml files that we can use to run our model with the modified data. To do this, we will need to enter into each directory and create the xml files for our materials, geometry, and settings.

# %% [markdown]
# Let's define the functions to create our models.

# %%
def createModel(xs_directory):
    """
    Creates the materials.xml file needed to run the Jezebel model
    
    Parameters
    -------------

    xs_directory: "str: or "os.Path_like object"
        Directory that points to where the cross_sections.xml file is

    Returns
    -------------
    None
    
    """
    
    pu_metal = openmc.Material()
    pu_metal.add_nuclide('Pu239', 0.037047, 'ao')
    pu_metal.add_nuclide('Pu240', 0.0017512, 'ao')
    pu_metal.add_nuclide('Pu241', 0.00011674, 'ao')
    pu_metal.add_nuclide('Ga69', 8.26605216e-4, 'ao')
    pu_metal.add_nuclide('Ga71', 5.48594784e-4, 'ao')
    pu_metal.set_density('atom/b-cm', 0.04029014)
    
    materials = openmc.Materials([pu_metal,])

    materials.cross_sections = xs_directory
    
    materials.export_to_xml()

    #Create the geometry and export it to an xml file
    sphere_boundary = openmc.Sphere(r = 6.3849, boundary_type = 'vacuum')
    sphere_region = -sphere_boundary
    sphere_cell = openmc.Cell()
    sphere_cell.region = sphere_region
    sphere_cell.fill = pu_metal
    
    root_universe = openmc.Universe(cells = (sphere_cell,))
    
    geometry = openmc.Geometry(root_universe)
    geometry.export_to_xml()
    
def createSettings(temperature):
    """
    Creates the settings.xml file needed to run the Jezebel model
    
    Parameters
    -------------

    temperature: "int"
        Value that determines the default temperature of the model

    Returns
    -------------
    None
    
    """

    settings = openmc.Settings()

    bounds = [-7, -7, -7, 7, 7, 7]
    uniform_dist = openmc.stats.Box(bounds[:3], bounds[3:], only_fissionable = True)
    settings.source = openmc.IndependentSource(space = uniform_dist)
    
    settings.batches = 1000
    settings.inactive = 50
    settings.particles = 500000
    
    settings.temperature = {'default': temperature}
    settings.temperature['method'] = 'interpolation'
    
    settings.export_to_xml()

# %% [markdown]
# We then iterate through each set of folders containing our cross_sections.xml files, and use these functions to create models of Jezebel that will use our perturbed cross section data.

# %%
#Set the current working directory to the examples folder

os.chdir('examples')

#Save the starting directory

starting_directory = os.getcwd()

#Iterate through the direct perturbation folders and create the models

direct_perturbation_path = Path(direct_perturbation_models_directory)

for folder in direct_perturbation_path.iterdir():
    os.chdir(folder)
    createModel('cross_sections.xml')
    createSettings(temperature=300)
    os.chdir(starting_directory) 

#Iterate through the random sampling folders and create the models

random_sampling_path = Path(random_sampling_models_directory)

for folder in random_sampling_path.iterdir():
    os.chdir(folder)
    createModel('cross_sections.xml')
    createSettings(temperature=300)
    os.chdir(starting_directory)
# Out:
# /home/jacob/miniconda3/envs/openmc-env/lib/python3.13/site-packages/openmc/stats/multivariate.py:960: FutureWarning: The 'only_fissionable' has been deprecated. Use the 'constraints' argument when defining a source instead.
#   warn("The 'only_fissionable' has been deprecated. Use the "

# %% [markdown]
# We are now able to run our models of Jezebel to get the k_eff values needed to calculate the propagated uncertainty.

# %%
#Iterate through the direct perturbation folders and run OpenMC

counter = 0

for folder in direct_perturbation_path.iterdir():
    os.chdir(folder)
    openmc.run(output=False)
    counter += 1
    print('Direct Perturbation Run ' + str(counter) + ' Completed')
    print('\n')
    os.chdir(starting_directory)

#Iterate through the random sampling folders and run OpenMC

counter = 0

for folder in random_sampling_path.iterdir():
    os.chdir(folder)
    openmc.run(output=False)
    counter += 1
    print('Random Sampling Run ' + str(counter) + ' Completed')
    print('\n')
    os.chdir(starting_directory)

print('All Runs Completed')
# Out:
# Direct Perturbation Run 1 Completed
#
#
# Direct Perturbation Run 2 Completed
#
#
# Direct Perturbation Run 3 Completed
#
#
# Direct Perturbation Run 4 Completed
#
#
# Direct Perturbation Run 5 Completed
#
#
# Direct Perturbation Run 6 Completed
#
#
# Direct Perturbation Run 7 Completed
#
#
# Direct Perturbation Run 8 Completed
#
#
# Direct Perturbation Run 9 Completed
#
#
# Direct Perturbation Run 10 Completed
#
#
# Direct Perturbation Run 11 Completed
#
#
# Direct Perturbation Run 12 Completed
#
#
# Direct Perturbation Run 13 Completed
#
#
# Direct Perturbation Run 14 Completed
#
#
# Direct Perturbation Run 15 Completed
#
#
# Direct Perturbation Run 16 Completed
#
#
# Direct Perturbation Run 17 Completed
#
#
# Direct Perturbation Run 18 Completed
#
#
# Direct Perturbation Run 19 Completed
#
#
# Direct Perturbation Run 20 Completed
#
#
# Direct Perturbation Run 21 Completed
#
#
# Direct Perturbation Run 22 Completed
#
#
# Direct Perturbation Run 23 Completed
#
#
# Direct Perturbation Run 24 Completed
#
#
# Direct Perturbation Run 25 Completed
#
#
# Direct Perturbation Run 26 Completed
#
#
# Direct Perturbation Run 27 Completed
#
#
# Direct Perturbation Run 28 Completed
#
#
# Direct Perturbation Run 29 Completed
#
#
# Direct Perturbation Run 30 Completed
#
#
# Direct Perturbation Run 31 Completed
#
#
# Direct Perturbation Run 32 Completed
#
#
# Direct Perturbation Run 33 Completed
#
#
# Direct Perturbation Run 34 Completed
#
#
# Direct Perturbation Run 35 Completed
#
#
# Direct Perturbation Run 36 Completed
#
#
# Direct Perturbation Run 37 Completed
#
#
# Direct Perturbation Run 38 Completed
#
#
# Direct Perturbation Run 39 Completed
#
#
# Direct Perturbation Run 40 Completed
#
#
# Direct Perturbation Run 41 Completed
#
#
# Direct Perturbation Run 42 Completed
#
#
# Direct Perturbation Run 43 Completed
#
#
# Direct Perturbation Run 44 Completed
#
#
# Random Sampling Run 1 Completed
#
#
# Random Sampling Run 2 Completed
#
#
# Random Sampling Run 3 Completed
#
#
# Random Sampling Run 4 Completed
#
#
# Random Sampling Run 5 Completed
#
#
# Random Sampling Run 6 Completed
#
#
# Random Sampling Run 7 Completed
#
#
# Random Sampling Run 8 Completed
#
#
# Random Sampling Run 9 Completed
#
#
# Random Sampling Run 10 Completed
#
#
# Random Sampling Run 11 Completed
#
#
# Random Sampling Run 12 Completed
#
#
# Random Sampling Run 13 Completed
#
#
# Random Sampling Run 14 Completed
#
#
# Random Sampling Run 15 Completed
#
#
# Random Sampling Run 16 Completed
#
#
# Random Sampling Run 17 Completed
#
#
# Random Sampling Run 18 Completed
#
#
# Random Sampling Run 19 Completed
#
#
# Random Sampling Run 20 Completed
#
#
# Random Sampling Run 21 Completed
#
#
# Random Sampling Run 22 Completed
#
#
# Random Sampling Run 23 Completed
#
#
# Random Sampling Run 24 Completed
#
#
# Random Sampling Run 25 Completed
#
#
# Random Sampling Run 26 Completed
#
#
# Random Sampling Run 27 Completed
#
#
# Random Sampling Run 28 Completed
#
#
# Random Sampling Run 29 Completed
#
#
# Random Sampling Run 30 Completed
#
#
# Random Sampling Run 31 Completed
#
#
# Random Sampling Run 32 Completed
#
#
# Random Sampling Run 33 Completed
#
#
# Random Sampling Run 34 Completed
#
#
# Random Sampling Run 35 Completed
#
#
# Random Sampling Run 36 Completed
#
#
# Random Sampling Run 37 Completed
#
#
# Random Sampling Run 38 Completed
#
#
# Random Sampling Run 39 Completed
#
#
# Random Sampling Run 40 Completed
#
#
# Random Sampling Run 41 Completed
#
#
# Random Sampling Run 42 Completed
#
#
# Random Sampling Run 43 Completed
#
#
# Random Sampling Run 44 Completed
#
#
# Random Sampling Run 45 Completed
#
#
# Random Sampling Run 46 Completed
#
#
# Random Sampling Run 47 Completed
#
#
# Random Sampling Run 48 Completed
#
#
# Random Sampling Run 49 Completed
#
#
# Random Sampling Run 50 Completed
#
#
# Random Sampling Run 51 Completed
#
#
# Random Sampling Run 52 Completed
#
#
# Random Sampling Run 53 Completed
#
#
# Random Sampling Run 54 Completed
#
#
# Random Sampling Run 55 Completed
#
#
# Random Sampling Run 56 Completed
#
#
# Random Sampling Run 57 Completed
#
#
# Random Sampling Run 58 Completed
#
#
# Random Sampling Run 59 Completed
#
#
# Random Sampling Run 60 Completed
#
#
# Random Sampling Run 61 Completed
#
#
# Random Sampling Run 62 Completed
#
#
# Random Sampling Run 63 Completed
#
#
# Random Sampling Run 64 Completed
#
#
# Random Sampling Run 65 Completed
#
#
# Random Sampling Run 66 Completed
#
#
# Random Sampling Run 67 Completed
#
#
# Random Sampling Run 68 Completed
#
#
# Random Sampling Run 69 Completed
#
#
# Random Sampling Run 70 Completed
#
#
# Random Sampling Run 71 Completed
#
#
# Random Sampling Run 72 Completed
#
#
# Random Sampling Run 73 Completed
#
#
# Random Sampling Run 74 Completed
#
#
# Random Sampling Run 75 Completed
#
#
# Random Sampling Run 76 Completed
#
#
# Random Sampling Run 77 Completed
#
#
# Random Sampling Run 78 Completed
#
#
# Random Sampling Run 79 Completed
#
#
# Random Sampling Run 80 Completed
#
#
# Random Sampling Run 81 Completed
#
#
# Random Sampling Run 82 Completed
#
#
# Random Sampling Run 83 Completed
#
#
# Random Sampling Run 84 Completed
#
#
# Random Sampling Run 85 Completed
#
#
# Random Sampling Run 86 Completed
#
#
# Random Sampling Run 87 Completed
#
#
# Random Sampling Run 88 Completed
#
#
# Random Sampling Run 89 Completed
#
#
# Random Sampling Run 90 Completed
#
#
# Random Sampling Run 91 Completed
#
#
# Random Sampling Run 92 Completed
#
#
# Random Sampling Run 93 Completed
#
#
# Random Sampling Run 94 Completed
#
#
# Random Sampling Run 95 Completed
#
#
# Random Sampling Run 96 Completed
#
#
# Random Sampling Run 97 Completed
#
#
# Random Sampling Run 98 Completed
#
#
# Random Sampling Run 99 Completed
#
#
# Random Sampling Run 100 Completed
#
#
# All Runs Completed

# %% [markdown]
# We need one more piece of simulation data before we can proceed to our post-processing. We have to get an unperturbed k_eff value that will be used as part of the direct perturbation methodology.

# %%
#Set up the base model with unperturbed cross sections
os.mkdir('BaseModelFolder')
os.chdir('./BaseModelFolder')

xs_xml_path = '/mnt/c/Users/jacob/endfb80/endfb-viii.0-hdf5/cross_sections.xml'

createModel(xs_xml_path)
createSettings(temperature=300)

#Run the base model
openmc.run(output=False)

print('Base Model Run Completed')
# Out:
# /home/jacob/miniconda3/envs/openmc-env/lib/python3.13/site-packages/openmc/stats/multivariate.py:960: FutureWarning: The 'only_fissionable' has been deprecated. Use the 'constraints' argument when defining a source instead.
#   warn("The 'only_fissionable' has been deprecated. Use the "
# Base Model Run Completed

# %% [markdown]
# We now have completed all of the OpenMC runs required for our analysis.
