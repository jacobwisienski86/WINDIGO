# %% [markdown]
# In this series of examples, we will perform the uncertainty quantification procedure from start to finish. We will quantify the uncertainty in k_eff due to uncertainty in Pu-239's fission cross section data within a simplified model of the Jezebel experiment. In this notebook, we will focus on creating the necessary perturbed ACE files.

# %%
#Import necessary modules
import WINDIGO
import numpy as np
import os

#Set NJOY path
os.environ["NJOY"] = "/home/jacob/miniconda3/envs/openmc-env/bin/njoy"

# %% [markdown]
# We first need to generate an unperturbed ACE file for Pu-239. For the purposes of this analysis, we will use the energy bounds from the SCALE44 energy grid to define our perturbation boundaries. The SCALE44 energy grid is given here: https://serpent.vtt.fi/mediawiki/index.php/SCALE_44-group_structure

# %%
#Input SCALE44 energy grid
scale44_grid_MeV = np.array([1.0000E-11, 3.0000E-9, 7.5000E-9, 1.0000E-8, 2.5300E-8,
                             3.0000E-8, 4.0000E-8, 5.0000E-8, 7.0000E-8, 1.0000E-7,
                             1.5000E-7, 2.0000E-7, 2.2500E-7, 2.5000E-7, 2.7500E-7,
                             3.2500E-7, 3.5000E-7, 3.7500E-7, 4.0000E-7, 6.2500E-7, 
                             1.0000E-6, 1.7700E-6, 3.0000E-6, 4.7500E-6, 6.0000E-6,
                             8.1000E-6, 1.0000E-5, 3.0000E-5, 1.0000E-4, 5.5000E-4,
                             3.0000E-3, 1.7000E-2, 2.5000E-2, 1.0000E-1, 4.0000E-1,
                             9.0000E-1, 1.4000E0, 1.8500E0, 2.3540E0, 2.4790E0,
                             3.0000E0, 4.8000E0, 6.4340E0, 8.1873E0, 2.0000E1])

#Convert to eV
scale44_grid_eV = scale44_grid_MeV * 10**6

#Generate the unperturbed Pu-239 ACE file
unperturbed_pu239_path = WINDIGO.generate_unperturbed_neutron_ace_file(
    frendy_Path="/mnt/c/Users/jacob/frendy_20241030",
    endf_Path=(
        "/mnt/c/Users/jacob/frendy_20241030/ENDF-B-VIII.0"
        "/ENDF-B-VIII.0/neutrons/n-094_Pu_239.endf"
    ),
    temperature=300,
    nuclide="Pu239",
    upgrade_Flag=True,
    energy_grid=scale44_grid_eV,
    cleanup_Flag=True
)
# Out:
# The path to the ace file generation input is: /mnt/c/Users/jacob/frendy_20241030/frendy/main/Pu239_acegenerator_upgrade.dat
#
#
# /////////////////////////////////////////////////////////////////////////////////////////
# //                                                                                     //
# //  //////////  ///////////    //////////  /////      ///  /////////    ///       ///  //
# //  ///         ///      ///   ///         //////     ///  ///     ///   ///     ///   //
# //  ///         ///      ///   ///         /// ///    ///  ///      ///   ///   ///    //
# //  //////////  ///////////    //////////  ///  ///   ///  ///       ///   ///////     //
# //  ///         ///    ///     ///         ///   ///  ///  ///       ///     ///       //
# //  ///         ///     ///    ///         ///    /// ///  ///      ///      ///       //
# //  ///         ///      ///   ///         ///     //////  ///     ///       ///       //
# //  ///         ///       ///  //////////  ///      /////  /////////         ///       //
# //                                                                                     //
# /////////////////////////////////////////////////////////////////////////////////////////
#
# FRENDY calculation date : 2026/04/05 22:58:44
#
#   Version : 2.05.000 (2024/Oct/30)
#   Developed by Japan Atomic Energy Agency
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
#   === Input file information (original) ===
#     Input file name : /mnt/c/Users/jacob/frendy_20241030/frendy/main/Pu239_acegenerator_upgrade.dat
#
#         ace_file_generation_fast_mode
#             nucl_file_name    /mnt/c/Users/jacob/frendy_20241030/ENDF-B-VIII.0/ENDF-B-VIII.0/neutrons/n-094_Pu_239.dat
#             temp    300
#             ace_file_name    Pu239_upgrade.ace
#             add_grid_data    (1.1e-05
#                 0.002999
#                 0.003001
#                 0.007499
#                 0.007501
#                 0.009999000000000001
#                 0.010001
#                 0.025299000000000002
#                 0.025301000000000004
#                 0.029998999999999998
#                 0.030001
#                 0.039999
#                 0.040001
#                 0.049998999999999995
#                 0.050001
#                 0.069999
#                 0.07000100000000001
#                 0.09999899999999999
#                 0.10000099999999999
#                 0.149999
#                 0.150001
#                 0.19999899999999998
#                 0.20000099999999998
#                 0.22499899999999998
#                 0.22500099999999998
#                 0.249999
#                 0.250001
#                 0.27499900000000005
#                 0.275001
#                 0.32499900000000004
#                 0.325001
#                 0.349999
#                 0.35000099999999995
#                 0.374999
#                 0.375001
#                 0.399999
#                 0.40000099999999994
#                 0.624999
#                 0.625001
#                 0.999999
#                 1.000001
#                 1.769999
#                 1.770001
#                 2.999999
#                 3.000001
#                 4.749999
#                 4.750001
#                 5.999999
#                 6.000001
#                 8.099999
#                 8.100000999999999
#                 9.999999
#                 10.000001
#                 29.999999
#                 30.000001
#                 99.9
#                 100.1
#                 549.9
#                 550.1
#                 2999.9
#                 3000.1
#                 16999.9
#                 17000.1
#                 24999.9
#                 25000.1
#                 99000.0
#                 101000.0
#                 399000.0
#                 401000.0
#                 899000.0
#                 901000.0
#                 1399000.0
#                 1401000.0
#                 1849000.0
#                 1851000.0
#                 2353000.0
#                 2355000.0
#                 2478000.0
#                 2480000.0
#                 2999000.0
#                 3001000.0
#                 4799000.0
#                 4801000.0
#                 6433000.0
#                 6435000.0
#                 8186300.000000001
#                 8188300.000000001
#                 19999000.0)
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
#   === Input file information (without comment) ===
#     Input file name : /mnt/c/Users/jacob/frendy_20241030/frendy/main/Pu239_acegenerator_upgrade.dat
#
#         ace_file_generation_fast_mode
#         nucl_file_name    /mnt/c/Users/jacob/frendy_20241030/ENDF-B-VIII.0/ENDF-B-VIII.0/neutrons/n-094_Pu_239.dat
#         temp    300
#         ace_file_name    Pu239_upgrade.ace
#         add_grid_data    (1.1e-05
#         0.002999
#         0.003001
#         0.007499
#         0.007501
#         0.009999000000000001
#         0.010001
#         0.025299000000000002
#         0.025301000000000004
#         0.029998999999999998
#         0.030001
#         0.039999
#         0.040001
#         0.049998999999999995
#         0.050001
#         0.069999
#         0.07000100000000001
#         0.09999899999999999
#         0.10000099999999999
#         0.149999
#         0.150001
#         0.19999899999999998
#         0.20000099999999998
#         0.22499899999999998
#         0.22500099999999998
#         0.249999
#         0.250001
#         0.27499900000000005
#         0.275001
#         0.32499900000000004
#         0.325001
#         0.349999
#         0.35000099999999995
#         0.374999
#         0.375001
#         0.399999
#         0.40000099999999994
#         0.624999
#         0.625001
#         0.999999
#         1.000001
#         1.769999
#         1.770001
#         2.999999
#         3.000001
#         4.749999
#         4.750001
#         5.999999
#         6.000001
#         8.099999
#         8.100000999999999
#         9.999999
#         10.000001
#         29.999999
#         30.000001
#         99.9
#         100.1
#         549.9
#         550.1
#         2999.9
#         3000.1
#         16999.9
#         17000.1
#         24999.9
#         25000.1
#         99000.0
#         101000.0
#         399000.0
#         401000.0
#         899000.0
#         901000.0
#         1399000.0
#         1401000.0
#         1849000.0
#         1851000.0
#         2353000.0
#         2355000.0
#         2478000.0
#         2480000.0
#         2999000.0
#         3001000.0
#         4799000.0
#         4801000.0
#         6433000.0
#         6435000.0
#         8186300.000000001
#         8188300.000000001
#         19999000.0)
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# === Read input data for ReconResonance ===
#   nucl_file_name     : /mnt/c/Users/jacob/frendy_20241030/ENDF-B-VIII.0/ENDF-B-VIII.0/neutrons/n-094_Pu_239.dat
#   add_grid_data [eV]
#     1 / 88 : 1.1e-05
#     2 / 88 : 0.002999
#     3 / 88 : 0.003001
#     4 / 88 : 0.007499
#     5 / 88 : 0.007501
#     6 / 88 : 0.009999000000000001
#     7 / 88 : 0.010001
#     8 / 88 : 0.025299000000000002
#     9 / 88 : 0.025301000000000004
#     10 / 88 : 0.029998999999999998
#     11 / 88 : 0.030001
#     12 / 88 : 0.039999
#     13 / 88 : 0.040001
#     14 / 88 : 0.049998999999999995
#     15 / 88 : 0.050001
#     16 / 88 : 0.069999
#     17 / 88 : 0.07000100000000001
#     18 / 88 : 0.09999899999999999
#     19 / 88 : 0.10000099999999999
#     20 / 88 : 0.149999
#     21 / 88 : 0.150001
#     22 / 88 : 0.19999899999999998
#     23 / 88 : 0.20000099999999998
#     24 / 88 : 0.22499899999999998
#     25 / 88 : 0.22500099999999998
#     26 / 88 : 0.249999
#     27 / 88 : 0.250001
#     28 / 88 : 0.27499900000000005
#     29 / 88 : 0.275001
#     30 / 88 : 0.32499900000000004
#     31 / 88 : 0.325001
#     32 / 88 : 0.349999
#     33 / 88 : 0.35000099999999995
#     34 / 88 : 0.374999
#     35 / 88 : 0.375001
#     36 / 88 : 0.399999
#     37 / 88 : 0.40000099999999994
#     38 / 88 : 0.624999
#     39 / 88 : 0.625001
#     40 / 88 : 0.999999
#     41 / 88 : 1.000001
#     42 / 88 : 1.769999
#     43 / 88 : 1.770001
#     44 / 88 : 2.999999
#     45 / 88 : 3.000001
#     46 / 88 : 4.749999
#     47 / 88 : 4.750001
#     48 / 88 : 5.999999
#     49 / 88 : 6.000001
#     50 / 88 : 8.099999
#     51 / 88 : 8.100000999999999
#     52 / 88 : 9.999999
#     53 / 88 : 10.000001
#     54 / 88 : 29.999999
#     55 / 88 : 30.000001
#     56 / 88 : 99.9
#     57 / 88 : 100.1
#     58 / 88 : 549.9
#     59 / 88 : 550.1
#     60 / 88 : 2999.9
#     61 / 88 : 3000.1
#     62 / 88 : 16999.9
#     63 / 88 : 17000.1
#     64 / 88 : 24999.9
#     65 / 88 : 25000.1
#     66 / 88 : 99000.0
#     67 / 88 : 101000.0
#     68 / 88 : 399000.0
#     69 / 88 : 401000.0
#     70 / 88 : 899000.0
#     71 / 88 : 901000.0
#     72 / 88 : 1399000.0
#     73 / 88 : 1401000.0
#     74 / 88 : 1849000.0
#     75 / 88 : 1851000.0
#     76 / 88 : 2353000.0
#     77 / 88 : 2355000.0
#     78 / 88 : 2478000.0
#     79 / 88 : 2480000.0
#     80 / 88 : 2999000.0
#     81 / 88 : 3001000.0
#     82 / 88 : 4799000.0
#     83 / 88 : 4801000.0
#     84 / 88 : 6433000.0
#     85 / 88 : 6435000.0
#     86 / 88 : 8186300.000000001
#     87 / 88 : 8188300.000000001
#     88 / 88 : 19999000.0
# === Read input data for DopplerBroadening ===
#   nucl_file_name          : /mnt/c/Users/jacob/frendy_20241030/ENDF-B-VIII.0/ENDF-B-VIII.0/neutrons/n-094_Pu_239.dat
#   temp [K]                : 300
# === Read input data for GasProduction ===
#   nucl_file_name          : /mnt/c/Users/jacob/frendy_20241030/ENDF-B-VIII.0/ENDF-B-VIII.0/neutrons/n-094_Pu_239.dat
# === Read input data for ProbTable ===
#   nucl_file_name          : /mnt/c/Users/jacob/frendy_20241030/ENDF-B-VIII.0/ENDF-B-VIII.0/neutrons/n-094_Pu_239.dat
# === Read input data for ThermalScatter ===
#   nucl_file_name                : /mnt/c/Users/jacob/frendy_20241030/ENDF-B-VIII.0/ENDF-B-VIII.0/neutrons/n-094_Pu_239.dat
# === Read input data for AceDataGenerator ===
#   nucl_file_name                       : /mnt/c/Users/jacob/frendy_20241030/ENDF-B-VIII.0/ENDF-B-VIII.0/neutrons/n-094_Pu_239.dat
#   ace_file_name                        : Pu239_upgrade.ace
# ****************************** Resonance reconstruct calculation ******************************
#
# FRENDY calculation date : 2026/04/05 22:58:50
#
# === Nuclear data information ===
#   Material No.       : 9437
#   Material Data (ZA) : 94239
#   Mass               : 236.999
#
# === Set data information ===
#   Error             : 0.001
#   Integral Error    : 5e-08
#   Maximum Error     : 0.01
#   Temperature       : 0
#   Additional Energy Grid
#     1.1e-05  0.002999  0.003001  0.007499  0.007501  0.009999  0.010001  0.025299  0.025301  0.029999  0.030001  0.039999  0.040001  0.049999  0.050001  0.069999  0.070001  0.099999  0.100001  0.149999  0.150001  0.199999  0.200001  0.224999  0.225001  0.249999  0.250001  0.274999  0.275001  0.324999  0.325001  0.349999  0.350001  0.374999  0.375001  0.399999  0.400001  0.624999  0.625001  0.999999  1  1.77  1.77  3  3  4.75  4.75  6  6  8.1  8.1  10  10  30  30  99.9  100.1  549.9  550.1  2999.9  3000.1  16999.9  17000.1  24999.9  25000.1  99000  101000  399000  401000  899000  901000  1.399e+06  1.401e+06  1.849e+06  1.851e+06  2.353e+06  2.355e+06  2.478e+06  2.48e+06  2.999e+06  3.001e+06  4.799e+06  4.801e+06  6.433e+06  6.435e+06  8.1863e+06  8.1883e+06  1.9999e+07
#
#
# Number of resonance energy grids after ResonanceEnergyGridLinearizer
#   1 / 1 : 2
#     1 / 2 : 3523
#     2 / 2 : 144
#
#
# =====================
# =                   =
# =  --- CAUTION ---  =
# =                   =
# =====================
#
#   <Class name>
#     ResonanceXSCalculator
#
#   <Function name>
#     check_ene_data(int i, int j, vector<Real8>& ene_data)
#
#   <Warning message>
#     Number of isotopes (NIS)               : 1 / 1
#     Number of resonance energy range (NER) : 1 / 2
#     Lower limit for an energy range (EL)   : 1e-05
#     Upper limit for an energy range (EH)   : 2500
#     Set energy grid data                   : 2500
#     The set energy grid data is not within the energy range.
#
#
# =====================
# =                   =
# =  --- CAUTION ---  =
# =                   =
# =====================
#
#   <Class name>
#     ResonanceXSCalculator
#
#   <Function name>
#     check_ene_data(int i, int j, vector<Real8>& ene_data)
#
#   <Warning message>
#     Number of isotopes (NIS)               : 1 / 1
#     Number of resonance energy range (NER) : 2 / 2
#     Lower limit for an energy range (EL)   : 2500
#     Upper limit for an energy range (EH)   : 30000
#     Set energy grid data                   : 2500
#     The set energy grid data is not within the energy range.
#
# Total calculation time : 10.92 [s]
#   Number of energy grid
#     Total grid number     : 215492
#     Resonance grid number :
#         214774	(Isotopes No. = 1, Resonance energy ranges No. = 1)
#         141	(Isotopes No. = 1, Resonance energy ranges No. = 2)
#
# ***********************************************************************************************
#
# ****************************** Doppler broadening calculation ******************************
#
# FRENDY calculation date : 2026/04/05 22:59:02
#
# === Nuclear data information ===
#   Material No.       : 9437
#   Material Data (ZA) : 94239
#   Mass               : 236.999
#   Error              : 0.001
#
# === Set data information ===
#   Start Temperature    : 0
#   Final Temperature    : 300
#   Input Maximum Energy : 1e+06
#   Error                : 0.001
#   Integral Error       : 5e-08
#   Maximum Error        : 0.01
#
#
# =====================
# =                   =
# =  --- CAUTION ---  =
# =                   =
# =====================
#
#   <Class name>
#     DopplerCalculator
#
#   <Function name>
#     search_dop_ene_max()
#
#   <Warning message>
#     Maximum energy for broader and thinning (input) : 1e+06
#     Upper limit of resolved resonance region        : 2500
#     Maximum energy for broader and thinning is larger than
#     the upper limit of resolved resonance region.
#     The maximum energy is modified to the upper limit of the
#     resonance region.
#
# Max energy for broader and thinning : 2500 [eV]
# Total calculation time              : 7.36 [s]
#
# ********************************************************************************************
#
# ****************************** Gas production XS calculation ******************************
#
# FRENDY calculation date : 2026/04/05 22:59:10
#
# === Nuclear data information (Original nuclear data) ===
#   Material No.       : 9437
#   Material Data (ZA) : 94239
#   Mass               : 236.999
#   Temperature        : 0
#
# === Nuclear data information (Doppler broadened nuclear data) ===
#   Material No.       : 9437
#   Material Data (ZA) : 94239
#   Mass               : 236.999
#   Temperature        : 300
#
#  pendf mt  mt203  mt204  mt205  mt206  mt207
#  -------- ------ ------ ------ ------ ------
#
# Total calculation time : 0.06 [s]
#
# ********************************************************************************************
#
# ****************************** Probability Table calculation ******************************
#
# FRENDY calculation date : 2026/04/05 22:59:10
#
# === Nuclear data information ===
#   Material No.       : 9437
#   Material Data (ZA) : 94239
#   Mass               : 236.999
#
# === Set data information ===
#   Sample No.           :  10000 (Energy grid No. per ladder)
#   Seed of Random No.   :  12345
#   Ladder No.           :    100
#   Error                :   0.05
#   Bin No.              :     20
#   Energy Grid No.      :      0
#   Temperature
#     300
#   Sigma Zero Data
#     1e+10  10000  1000  300  100  30  10  1  0.1  1e-05
#
#       temp = 300.000, lad_no =   10 : statistical error of p_tab * xs by clt (tot) = 3.585e-02 / 7.962e-02 (ave / max)
#       temp = 300.000, lad_no =   20 : statistical error of p_tab * xs by clt (tot) = 2.848e-02 / 6.759e-02 (ave / max)
#       temp = 300.000, lad_no =   30 : statistical error of p_tab * xs by clt (tot) = 2.424e-02 / 5.851e-02 (ave / max)
#       temp = 300.000, lad_no =   40 : statistical error of p_tab * xs by clt (tot) = 2.007e-02 / 4.625e-02 (ave / max)
#       temp = 300.000, lad_no =   40 : statistical error of p_tab * xs by clt (ela) = 1.317e-02 / 2.318e-02 (ave / max)
#       temp = 300.000, lad_no =   40 : statistical error of p_tab * xs by clt (fis) = 5.459e-03 / 1.759e-02 (ave / max)
#       temp = 300.000, lad_no =   40 : statistical error of p_tab * xs by clt (rad) = 2.678e-03 / 8.907e-03 (ave / max)
#     Calculation time of energy (  1/ 71) :2.5e+03 [eV] :  0.62 [s]
#       temp = 300.000, lad_no =   10 : statistical error of p_tab * xs by clt (tot) = 3.728e-02 / 9.048e-02 (ave / max)
#       temp = 300.000, lad_no =   20 : statistical error of p_tab * xs by clt (tot) = 2.596e-02 / 5.903e-02 (ave / max)
#       temp = 300.000, lad_no =   30 : statistical error of p_tab * xs by clt (tot) = 1.988e-02 / 4.378e-02 (ave / max)
#       temp = 300.000, lad_no =   30 : statistical error of p_tab * xs by clt (ela) = 1.397e-02 / 2.481e-02 (ave / max)
#       temp = 300.000, lad_no =   30 : statistical error of p_tab * xs by clt (fis) = 3.794e-03 / 1.268e-02 (ave / max)
#       temp = 300.000, lad_no =   30 : statistical error of p_tab * xs by clt (rad) = 3.302e-03 / 9.675e-03 (ave / max)
#     Calculation time of energy (  2/ 71) :2.55e+03 [eV] :  0.41 [s]
#       temp = 300.000, lad_no =   10 : statistical error of p_tab * xs by clt (tot) = 3.319e-02 / 8.189e-02 (ave / max)
#       temp = 300.000, lad_no =   20 : statistical error of p_tab * xs by clt (tot) = 2.749e-02 / 6.229e-02 (ave / max)
#       temp = 300.000, lad_no =   30 : statistical error of p_tab * xs by clt (tot) = 2.193e-02 / 4.872e-02 (ave / max)
#       temp = 300.000, lad_no =   30 : statistical error of p_tab * xs by clt (ela) = 1.533e-02 / 2.999e-02 (ave / max)
#       temp = 300.000, lad_no =   30 : statistical error of p_tab * xs by clt (fis) = 4.673e-03 / 1.498e-02 (ave / max)
#       temp = 300.000, lad_no =   30 : statistical error of p_tab * xs by clt (rad) = 3.789e-03 / 1.225e-02 (ave / max)
#     Calculation time of energy (  3/ 71) :2.65e+03 [eV] :  0.47 [s]
#       temp = 300.000, lad_no =   10 : statistical error of p_tab * xs by clt (tot) = 3.783e-02 / 1.001e-01 (ave / max)
#       temp = 300.000, lad_no =   20 : statistical error of p_tab * xs by clt (tot) = 2.564e-02 / 5.487e-02 (ave / max)
#       temp = 300.000, lad_no =   30 : statistical error of p_tab * xs by clt (tot) = 2.124e-02 / 4.510e-02 (ave / max)
#       temp = 300.000, lad_no =   30 : statistical error of p_tab * xs by clt (ela) = 1.421e-02 / 2.505e-02 (ave / max)
#       temp = 300.000, lad_no =   30 : statistical error of p_tab * xs by clt (fis) = 5.921e-03 / 1.882e-02 (ave / max)
#       temp = 300.000, lad_no =   30 : statistical error of p_tab * xs by clt (rad) = 2.492e-03 / 7.888e-03 (ave / max)
#     Calculation time of energy (  4/ 71) :2.75e+03 [eV] :  0.48 [s]
#       temp = 300.000, lad_no =   10 : statistical error of p_tab * xs by clt (tot) = 3.789e-02 / 9.609e-02 (ave / max)
#       temp = 300.000, lad_no =   20 : statistical error of p_tab * xs by clt (tot) = 2.740e-02 / 7.057e-02 (ave / max)
#       temp = 300.000, lad_no =   30 : statistical error of p_tab * xs by clt (tot) = 2.204e-02 / 5.231e-02 (ave / max)
#       temp = 300.000, lad_no =   40 : statistical error of p_tab * xs by clt (tot) = 1.872e-02 / 4.487e-02 (ave / max)
#       temp = 300.000, lad_no =   40 : statistical error of p_tab * xs by clt (ela) = 1.239e-02 / 2.413e-02 (ave / max)
#       temp = 300.000, lad_no =   40 : statistical error of p_tab * xs by clt (fis) = 5.198e-03 / 1.567e-02 (ave / max)
#       temp = 300.000, lad_no =   40 : statistical error of p_tab * xs by clt (rad) = 2.447e-03 / 8.264e-03 (ave / max)
#     Calculation time of energy (  5/ 71) :2.85e+03 [eV] :  0.64 [s]
#       temp = 300.000, lad_no =   10 : statistical error of p_tab * xs by clt (tot) = 3.881e-02 / 1.075e-01 (ave / max)
#       temp = 300.000, lad_no =   20 : statistical error of p_tab * xs by clt (tot) = 3.139e-02 / 8.091e-02 (ave / max)
#       temp = 300.000, lad_no =   30 : statistical error of p_tab * xs by clt (tot) = 2.564e-02 / 6.289e-02 (ave / max)
#       temp = 300.000, lad_no =   40 : statistical error of p_tab * xs by clt (tot) = 2.237e-02 / 5.760e-02 (ave / max)
#       temp = 300.000, lad_no =   50 : statistical error of p_tab * xs by clt (tot) = 1.972e-02 / 4.889e-02 (ave / max)
#       temp = 300.000, lad_no =   50 : statistical error of p_tab * xs by clt (ela) = 1.406e-02 / 3.067e-02 (ave / max)
#       temp = 300.000, lad_no =   50 : statistical error of p_tab * xs by clt (fis) = 3.627e-03 / 1.177e-02 (ave / max)
#       temp = 300.000, lad_no =   50 : statistical error of p_tab * xs by clt (rad) = 3.371e-03 / 1.074e-02 (ave / max)
#     Calculation time of energy (  6/ 71) :2.95e+03 [eV] :  0.71 [s]
#       temp = 300.000, lad_no =   10 : statistical error of p_tab * xs by clt (tot) = 3.221e-02 / 6.208e-02 (ave / max)
#       temp = 300.000, lad_no =   20 : statistical error of p_tab * xs by clt (tot) = 2.433e-02 / 4.594e-02 (ave / max)
#       temp = 300.000, lad_no =   20 : statistical error of p_tab * xs by clt (ela) = 1.760e-02 / 2.737e-02 (ave / max)
#       temp = 300.000, lad_no =   20 : statistical error of p_tab * xs by clt (fis) = 5.023e-03 / 1.461e-02 (ave / max)
#       temp = 300.000, lad_no =   20 : statistical error of p_tab * xs by clt (rad) = 3.146e-03 / 9.100e-03 (ave / max)
#     Calculation time of energy (  7/ 71) :3.05e+03 [eV] :  0.32 [s]
#       temp = 300.000, lad_no =   10 : statistical error of p_tab * xs by clt (tot) = 4.303e-02 / 1.154e-01 (ave / max)
#       temp = 300.000, lad_no =   20 : statistical error of p_tab * xs by clt (tot) = 2.803e-02 / 7.107e-02 (ave / max)
#       temp = 300.000, lad_no =   30 : statistical error of p_tab * xs by clt (tot) = 2.283e-02 / 5.304e-02 (ave / max)
#       temp = 300.000, lad_no =   40 : statistical error of p_tab * xs by clt (tot) = 2.052e-02 / 5.048e-02 (ave / max)
#       temp = 300.000, lad_no =   50 : statistical error of p_tab * xs by clt (tot) = 1.846e-02 / 4.638e-02 (ave / max)
#       temp = 300.000, lad_no =   50 : statistical error of p_tab * xs by clt (ela) = 1.215e-02 / 2.419e-02 (ave / max)
#       temp = 300.000, lad_no =   50 : statistical error of p_tab * xs by clt (fis) = 5.241e-03 / 1.841e-02 (ave / max)
#       temp = 300.000, lad_no =   50 : statistical error of p_tab * xs by clt (rad) = 2.047e-03 / 6.935e-03 (ave / max)
#     Calculation time of energy (  8/ 71) :3.15e+03 [eV] :  0.81 [s]
#       temp = 300.000, lad_no =   10 : statistical error of p_tab * xs by clt (tot) = 3.617e-02 / 7.108e-02 (ave / max)
#       temp = 300.000, lad_no =   20 : statistical error of p_tab * xs by clt (tot) = 2.669e-02 / 5.479e-02 (ave / max)
#       temp = 300.000, lad_no =   30 : statistical error of p_tab * xs by clt (tot) = 2.300e-02 / 5.457e-02 (ave / max)
#       temp = 300.000, lad_no =   40 : statistical error of p_tab * xs by clt (tot) = 1.980e-02 / 4.811e-02 (ave / max)
#       temp = 300.000, lad_no =   40 : statistical error of p_tab * xs by clt (ela) = 1.329e-02 / 2.595e-02 (ave / max)
#       temp = 300.000, lad_no =   40 : statistical error of p_tab * xs by clt (fis) = 5.091e-03 / 1.780e-02 (ave / max)
#       temp = 300.000, lad_no =   40 : statistical error of p_tab * xs by clt (rad) = 2.529e-03 / 7.749e-03 (ave / max)
#     Calculation time of energy (  9/ 71) :3.25e+03 [eV] :  0.66 [s]
#       temp = 300.000, lad_no =   10 : statistical error of p_tab * xs by clt (tot) = 3.181e-02 / 6.887e-02 (ave / max)
#       temp = 300.000, lad_no =   20 : statistical error of p_tab * xs by clt (tot) = 2.194e-02 / 4.751e-02 (ave / max)
#       temp = 300.000, lad_no =   20 : statistical error of p_tab * xs by clt (ela) = 1.686e-02 / 2.990e-02 (ave / max)
#       temp = 300.000, lad_no =   20 : statistical error of p_tab * xs by clt (fis) = 2.964e-03 / 8.569e-03 (ave / max)
#       temp = 300.000, lad_no =   20 : statistical error of p_tab * xs by clt (rad) = 3.254e-03 / 1.149e-02 (ave / max)
#     Calculation time of energy ( 10/ 71) :3.35e+03 [eV] :  0.32 [s]
#       temp = 300.000, lad_no =   10 : statistical error of p_tab * xs by clt (tot) = 3.391e-02 / 7.842e-02 (ave / max)
#       temp = 300.000, lad_no =   20 : statistical error of p_tab * xs by clt (tot) = 2.226e-02 / 4.496e-02 (ave / max)
#       temp = 300.000, lad_no =   20 : statistical error of p_tab * xs by clt (ela) = 1.648e-02 / 3.146e-02 (ave / max)
#       temp = 300.000, lad_no =   20 : statistical error of p_tab * xs by clt (fis) = 3.945e-03 / 1.355e-02 (ave / max)
#       temp = 300.000, lad_no =   20 : statistical error of p_tab * xs by clt (rad) = 3.201e-03 / 9.484e-03 (ave / max)
#     Calculation time of energy ( 11/ 71) :3.45e+03 [eV] :  0.32 [s]
#       temp = 300.000, lad_no =   10 : statistical error of p_tab * xs by clt (tot) = 2.993e-02 / 5.323e-02 (ave / max)
#       temp = 300.000, lad_no =   20 : statistical error of p_tab * xs by clt (tot) = 2.117e-02 / 4.170e-02 (ave / max)
#       temp = 300.000, lad_no =   20 : statistical error of p_tab * xs by clt (ela) = 1.588e-02 / 2.832e-02 (ave / max)
#       temp = 300.000, lad_no =   20 : statistical error of p_tab * xs by clt (fis) = 3.757e-03 / 1.206e-02 (ave / max)
#       temp = 300.000, lad_no =   20 : statistical error of p_tab * xs by clt (rad) = 2.637e-03 / 7.318e-03 (ave / max)
#     Calculation time of energy ( 12/ 71) :3.55e+03 [eV] :  0.33 [s]
#       temp = 300.000, lad_no =   10 : statistical error of p_tab * xs by clt (tot) = 3.303e-02 / 9.220e-02 (ave / max)
#       temp = 300.000, lad_no =   20 : statistical error of p_tab * xs by clt (tot) = 2.616e-02 / 6.352e-02 (ave / max)
#       temp = 300.000, lad_no =   30 : statistical error of p_tab * xs by clt (tot) = 2.281e-02 / 5.500e-02 (ave / max)
#       temp = 300.000, lad_no =   40 : statistical error of p_tab * xs by clt (tot) = 1.971e-02 / 4.631e-02 (ave / max)
#       temp = 300.000, lad_no =   40 : statistical error of p_tab * xs by clt (ela) = 1.455e-02 / 3.284e-02 (ave / max)
#       temp = 300.000, lad_no =   40 : statistical error of p_tab * xs by clt (fis) = 2.880e-03 / 8.370e-03 (ave / max)
#       temp = 300.000, lad_no =   40 : statistical error of p_tab * xs by clt (rad) = 3.106e-03 / 9.028e-03 (ave / max)
#     Calculation time of energy ( 13/ 71) :3.65e+03 [eV] :  0.67 [s]
#       temp = 300.000, lad_no =   10 : statistical error of p_tab * xs by clt (tot) = 3.507e-02 / 8.546e-02 (ave / max)
#       temp = 300.000, lad_no =   20 : statistical error of p_tab * xs by clt (tot) = 2.454e-02 / 4.989e-02 (ave / max)
#       temp = 300.000, lad_no =   20 : statistical error of p_tab * xs by clt (ela) = 1.757e-02 / 3.027e-02 (ave / max)
#       temp = 300.000, lad_no =   20 : statistical error of p_tab * xs by clt (fis) = 5.510e-03 / 1.463e-02 (ave / max)
#       temp = 300.000, lad_no =   20 : statistical error of p_tab * xs by clt (rad) = 2.786e-03 / 8.540e-03 (ave / max)
#     Calculation time of energy ( 14/ 71) :3.75e+03 [eV] :  0.37 [s]
#       temp = 300.000, lad_no =   10 : statistical error of p_tab * xs by clt (tot) = 4.266e-02 / 1.294e-01 (ave / max)
#       temp = 300.000, lad_no =   20 : statistical error of p_tab * xs by clt (tot) = 2.984e-02 / 7.830e-02 (ave / max)
#       temp = 300.000, lad_no =   30 : statistical error of p_tab * xs by clt (tot) = 2.384e-02 / 6.161e-02 (ave / max)
#       temp = 300.000, lad_no =   40 : statistical error of p_tab * xs by clt (tot) = 2.065e-02 / 5.329e-02 (ave / max)
#       temp = 300.000, lad_no =   50 : statistical error of p_tab * xs by clt (tot) = 1.819e-02 / 4.514e-02 (ave / max)
#       temp = 300.000, lad_no =   50 : statistical error of p_tab * xs by clt (ela) = 1.293e-02 / 2.623e-02 (ave / max)
#       temp = 300.000, lad_no =   50 : statistical error of p_tab * xs by clt (fis) = 3.994e-03 / 1.395e-02 (ave / max)
#       temp = 300.000, lad_no =   50 : statistical error of p_tab * xs by clt (rad) = 2.259e-03 / 6.925e-03 (ave / max)
#     Calculation time of energy ( 15/ 71) :3.85e+03 [eV] :  0.94 [s]
#       temp = 300.000, lad_no =   10 : statistical error of p_tab * xs by clt (tot) = 3.345e-02 / 7.846e-02 (ave / max)
#       temp = 300.000, lad_no =   20 : statistical error of p_tab * xs by clt (tot) = 2.500e-02 / 6.070e-02 (ave / max)
#       temp = 300.000, lad_no =   30 : statistical error of p_tab * xs by clt (tot) = 2.127e-02 / 4.735e-02 (ave / max)
#       temp = 300.000, lad_no =   30 : statistical error of p_tab * xs by clt (ela) = 1.535e-02 / 2.914e-02 (ave / max)
#       temp = 300.000, lad_no =   30 : statistical error of p_tab * xs by clt (fis) = 4.251e-03 / 1.206e-02 (ave / max)
#       temp = 300.000, lad_no =   30 : statistical error of p_tab * xs by clt (rad) = 2.936e-03 / 9.139e-03 (ave / max)
#     Calculation time of energy ( 16/ 71) :3.95e+03 [eV] :  0.56 [s]
#       temp = 300.000, lad_no =   10 : statistical error of p_tab * xs by clt (tot) = 3.946e-02 / 1.029e-01 (ave / max)
#       temp = 300.000, lad_no =   20 : statistical error of p_tab * xs by clt (tot) = 2.671e-02 / 6.523e-02 (ave / max)
#       temp = 300.000, lad_no =   30 : statistical error of p_tab * xs by clt (tot) = 2.208e-02 / 5.062e-02 (ave / max)
#       temp = 300.000, lad_no =   40 : statistical error of p_tab * xs by clt (tot) = 1.806e-02 / 4.102e-02 (ave / max)
#       temp = 300.000, lad_no =   40 : statistical error of p_tab * xs by clt (ela) = 1.377e-02 / 2.761e-02 (ave / max)
#       temp = 300.000, lad_no =   40 : statistical error of p_tab * xs by clt (fis) = 2.835e-03 / 8.148e-03 (ave / max)
#       temp = 300.000, lad_no =   40 : statistical error of p_tab * xs by clt (rad) = 2.512e-03 / 9.173e-03 (ave / max)
#     Calculation time of energy ( 17/ 71) :4.12e+03 [eV] :  0.76 [s]
#       temp = 300.000, lad_no =   10 : statistical error of p_tab * xs by clt (tot) = 3.568e-02 / 7.409e-02 (ave / max)
#       temp = 300.000, lad_no =   20 : statistical error of p_tab * xs by clt (tot) = 2.476e-02 / 5.141e-02 (ave / max)
#       temp = 300.000, lad_no =   30 : statistical error of p_tab * xs by clt (tot) = 2.109e-02 / 4.577e-02 (ave / max)
#       temp = 300.000, lad_no =   30 : statistical error of p_tab * xs by clt (ela) = 1.556e-02 / 2.942e-02 (ave / max)
#       temp = 300.000, lad_no =   30 : statistical error of p_tab * xs by clt (fis) = 3.863e-03 / 1.104e-02 (ave / max)
#       temp = 300.000, lad_no =   30 : statistical error of p_tab * xs by clt (rad) = 2.769e-03 / 8.024e-03 (ave / max)
#     Calculation time of energy ( 18/ 71) :4.38e+03 [eV] :  0.59 [s]
#       temp = 300.000, lad_no =   10 : statistical error of p_tab * xs by clt (tot) = 3.036e-02 / 8.672e-02 (ave / max)
#       temp = 300.000, lad_no =   20 : statistical error of p_tab * xs by clt (tot) = 2.223e-02 / 5.955e-02 (ave / max)
#       temp = 300.000, lad_no =   30 : statistical error of p_tab * xs by clt (tot) = 1.940e-02 / 4.864e-02 (ave / max)
#       temp = 300.000, lad_no =   30 : statistical error of p_tab * xs by clt (ela) = 1.439e-02 / 3.204e-02 (ave / max)
#       temp = 300.000, lad_no =   30 : statistical error of p_tab * xs by clt (fis) = 3.735e-03 / 1.076e-02 (ave / max)
#       temp = 300.000, lad_no =   30 : statistical error of p_tab * xs by clt (rad) = 2.282e-03 / 8.165e-03 (ave / max)
#     Calculation time of energy ( 19/ 71) :4.62e+03 [eV] :  0.58 [s]
#       temp = 300.000, lad_no =   10 : statistical error of p_tab * xs by clt (tot) = 3.908e-02 / 9.157e-02 (ave / max)
#       temp = 300.000, lad_no =   20 : statistical error of p_tab * xs by clt (tot) = 2.707e-02 / 5.717e-02 (ave / max)
#       temp = 300.000, lad_no =   30 : statistical error of p_tab * xs by clt (tot) = 2.094e-02 / 4.347e-02 (ave / max)
#       temp = 300.000, lad_no =   30 : statistical error of p_tab * xs by clt (ela) = 1.595e-02 / 3.001e-02 (ave / max)
#       temp = 300.000, lad_no =   30 : statistical error of p_tab * xs by clt (fis) = 3.236e-03 / 9.763e-03 (ave / max)
#       temp = 300.000, lad_no =   30 : statistical error of p_tab * xs by clt (rad) = 2.822e-03 / 7.886e-03 (ave / max)
#     Calculation time of energy ( 20/ 71) :4.88e+03 [eV] :  0.61 [s]
#       temp = 300.000, lad_no =   10 : statistical error of p_tab * xs by clt (tot) = 3.705e-02 / 9.057e-02 (ave / max)
#       temp = 300.000, lad_no =   20 : statistical error of p_tab * xs by clt (tot) = 2.618e-02 / 4.775e-02 (ave / max)
#       temp = 300.000, lad_no =   20 : statistical error of p_tab * xs by clt (ela) = 1.950e-02 / 3.150e-02 (ave / max)
#       temp = 300.000, lad_no =   20 : statistical error of p_tab * xs by clt (fis) = 4.710e-03 / 1.278e-02 (ave / max)
#       temp = 300.000, lad_no =   20 : statistical error of p_tab * xs by clt (rad) = 3.181e-03 / 7.681e-03 (ave / max)
#     Calculation time of energy ( 21/ 71) :5.12e+03 [eV] :  0.43 [s]
#       temp = 300.000, lad_no =   10 : statistical error of p_tab * xs by clt (tot) = 3.500e-02 / 7.201e-02 (ave / max)
#       temp = 300.000, lad_no =   20 : statistical error of p_tab * xs by clt (tot) = 2.595e-02 / 4.741e-02 (ave / max)
#       temp = 300.000, lad_no =   20 : statistical error of p_tab * xs by clt (ela) = 1.987e-02 / 3.341e-02 (ave / max)
#       temp = 300.000, lad_no =   20 : statistical error of p_tab * xs by clt (fis) = 4.012e-03 / 1.037e-02 (ave / max)
#       temp = 300.000, lad_no =   20 : statistical error of p_tab * xs by clt (rad) = 3.037e-03 / 7.926e-03 (ave / max)
#     Calculation time of energy ( 22/ 71) :5.38e+03 [eV] :   0.4 [s]
#       temp = 300.000, lad_no =   10 : statistical error of p_tab * xs by clt (tot) = 3.264e-02 / 6.439e-02 (ave / max)
#       temp = 300.000, lad_no =   20 : statistical error of p_tab * xs by clt (tot) = 2.298e-02 / 4.636e-02 (ave / max)
#       temp = 300.000, lad_no =   20 : statistical error of p_tab * xs by clt (ela) = 1.748e-02 / 3.190e-02 (ave / max)
#       temp = 300.000, lad_no =   20 : statistical error of p_tab * xs by clt (fis) = 4.003e-03 / 1.054e-02 (ave / max)
#       temp = 300.000, lad_no =   20 : statistical error of p_tab * xs by clt (rad) = 2.724e-03 / 6.961e-03 (ave / max)
#     Calculation time of energy ( 23/ 71) :5.62e+03 [eV] :  0.39 [s]
#       temp = 300.000, lad_no =   10 : statistical error of p_tab * xs by clt (tot) = 3.878e-02 / 1.135e-01 (ave / max)
#       temp = 300.000, lad_no =   20 : statistical error of p_tab * xs by clt (tot) = 2.720e-02 / 7.128e-02 (ave / max)
#       temp = 300.000, lad_no =   30 : statistical error of p_tab * xs by clt (tot) = 2.170e-02 / 5.749e-02 (ave / max)
#       temp = 300.000, lad_no =   40 : statistical error of p_tab * xs by clt (tot) = 1.911e-02 / 4.882e-02 (ave / max)
#       temp = 300.000, lad_no =   40 : statistical error of p_tab * xs by clt (ela) = 1.469e-02 / 3.380e-02 (ave / max)
#       temp = 300.000, lad_no =   40 : statistical error of p_tab * xs by clt (fis) = 3.119e-03 / 1.061e-02 (ave / max)
#       temp = 300.000, lad_no =   40 : statistical error of p_tab * xs by clt (rad) = 2.110e-03 / 6.780e-03 (ave / max)
#     Calculation time of energy ( 24/ 71) :5.88e+03 [eV] :  0.84 [s]
#       temp = 300.000, lad_no =   10 : statistical error of p_tab * xs by clt (tot) = 3.685e-02 / 9.863e-02 (ave / max)
#       temp = 300.000, lad_no =   20 : statistical error of p_tab * xs by clt (tot) = 2.712e-02 / 6.486e-02 (ave / max)
#       temp = 300.000, lad_no =   30 : statistical error of p_tab * xs by clt (tot) = 2.130e-02 / 5.040e-02 (ave / max)
#       temp = 300.000, lad_no =   40 : statistical error of p_tab * xs by clt (tot) = 1.893e-02 / 4.230e-02 (ave / max)
#       temp = 300.000, lad_no =   40 : statistical error of p_tab * xs by clt (ela) = 1.434e-02 / 2.895e-02 (ave / max)
#       temp = 300.000, lad_no =   40 : statistical error of p_tab * xs by clt (fis) = 3.224e-03 / 8.130e-03 (ave / max)
#       temp = 300.000, lad_no =   40 : statistical error of p_tab * xs by clt (rad) = 2.041e-03 / 6.773e-03 (ave / max)
#     Calculation time of energy ( 25/ 71) :6.12e+03 [eV] :  0.87 [s]
#       temp = 300.000, lad_no =   10 : statistical error of p_tab * xs by clt (tot) = 3.314e-02 / 7.459e-02 (ave / max)
#       temp = 300.000, lad_no =   20 : statistical error of p_tab * xs by clt (tot) = 2.516e-02 / 5.758e-02 (ave / max)
#       temp = 300.000, lad_no =   30 : statistical error of p_tab * xs by clt (tot) = 1.948e-02 / 4.091e-02 (ave / max)
#       temp = 300.000, lad_no =   30 : statistical error of p_tab * xs by clt (ela) = 1.530e-02 / 2.906e-02 (ave / max)
#       temp = 300.000, lad_no =   30 : statistical error of p_tab * xs by clt (fis) = 2.910e-03 / 8.041e-03 (ave / max)
#       temp = 300.000, lad_no =   30 : statistical error of p_tab * xs by clt (rad) = 2.205e-03 / 6.311e-03 (ave / max)
#     Calculation time of energy ( 26/ 71) :6.38e+03 [eV] :  0.65 [s]
#       temp = 300.000, lad_no =   10 : statistical error of p_tab * xs by clt (tot) = 3.089e-02 / 6.363e-02 (ave / max)
#       temp = 300.000, lad_no =   20 : statistical error of p_tab * xs by clt (tot) = 2.149e-02 / 3.886e-02 (ave / max)
#       temp = 300.000, lad_no =   20 : statistical error of p_tab * xs by clt (ela) = 1.707e-02 / 2.763e-02 (ave / max)
#       temp = 300.000, lad_no =   20 : statistical error of p_tab * xs by clt (fis) = 3.194e-03 / 9.043e-03 (ave / max)
#       temp = 300.000, lad_no =   20 : statistical error of p_tab * xs by clt (rad) = 2.309e-03 / 5.592e-03 (ave / max)
#     Calculation time of energy ( 27/ 71) :6.62e+03 [eV] :  0.43 [s]
#       temp = 300.000, lad_no =   10 : statistical error of p_tab * xs by clt (tot) = 3.230e-02 / 7.870e-02 (ave / max)
#       temp = 300.000, lad_no =   20 : statistical error of p_tab * xs by clt (tot) = 2.487e-02 / 6.024e-02 (ave / max)
#       temp = 300.000, lad_no =   30 : statistical error of p_tab * xs by clt (tot) = 1.974e-02 / 4.400e-02 (ave / max)
#       temp = 300.000, lad_no =   30 : statistical error of p_tab * xs by clt (ela) = 1.571e-02 / 3.162e-02 (ave / max)
#       temp = 300.000, lad_no =   30 : statistical error of p_tab * xs by clt (fis) = 2.558e-03 / 7.855e-03 (ave / max)
#       temp = 300.000, lad_no =   30 : statistical error of p_tab * xs by clt (rad) = 2.222e-03 / 5.840e-03 (ave / max)
#     Calculation time of energy ( 28/ 71) :6.88e+03 [eV] :  0.64 [s]
#       temp = 300.000, lad_no =   10 : statistical error of p_tab * xs by clt (tot) = 3.545e-02 / 7.777e-02 (ave / max)
#       temp = 300.000, lad_no =   20 : statistical error of p_tab * xs by clt (tot) = 2.641e-02 / 5.325e-02 (ave / max)
#       temp = 300.000, lad_no =   30 : statistical error of p_tab * xs by clt (tot) = 2.123e-02 / 4.500e-02 (ave / max)
#       temp = 300.000, lad_no =   30 : statistical error of p_tab * xs by clt (ela) = 1.697e-02 / 3.441e-02 (ave / max)
#       temp = 300.000, lad_no =   30 : statistical error of p_tab * xs by clt (fis) = 2.823e-03 / 7.690e-03 (ave / max)
#       temp = 300.000, lad_no =   30 : statistical error of p_tab * xs by clt (rad) = 2.201e-03 / 5.980e-03 (ave / max)
#     Calculation time of energy ( 29/ 71) :7.12e+03 [eV] :  0.62 [s]
#       temp = 300.000, lad_no =   10 : statistical error of p_tab * xs by clt (tot) = 3.702e-02 / 1.011e-01 (ave / max)
#       temp = 300.000, lad_no =   20 : statistical error of p_tab * xs by clt (tot) = 2.390e-02 / 5.907e-02 (ave / max)
#       temp = 300.000, lad_no =   30 : statistical error of p_tab * xs by clt (tot) = 1.896e-02 / 4.315e-02 (ave / max)
#       temp = 300.000, lad_no =   30 : statistical error of p_tab * xs by clt (ela) = 1.464e-02 / 3.115e-02 (ave / max)
#       temp = 300.000, lad_no =   30 : statistical error of p_tab * xs by clt (fis) = 3.339e-03 / 8.769e-03 (ave / max)
#       temp = 300.000, lad_no =   30 : statistical error of p_tab * xs by clt (rad) = 1.709e-03 / 4.798e-03 (ave / max)
#     Calculation time of energy ( 30/ 71) :7.38e+03 [eV] :  0.65 [s]
#       temp = 300.000, lad_no =   10 : statistical error of p_tab * xs by clt (tot) = 3.098e-02 / 7.844e-02 (ave / max)
#       temp = 300.000, lad_no =   20 : statistical error of p_tab * xs by clt (tot) = 2.595e-02 / 6.802e-02 (ave / max)
#       temp = 300.000, lad_no =   30 : statistical error of p_tab * xs by clt (tot) = 2.121e-02 / 5.468e-02 (ave / max)
#       temp = 300.000, lad_no =   40 : statistical error of p_tab * xs by clt (tot) = 1.828e-02 / 4.669e-02 (ave / max)
#       temp = 300.000, lad_no =   40 : statistical error of p_tab * xs by clt (ela) = 1.407e-02 / 3.372e-02 (ave / max)
#       temp = 300.000, lad_no =   40 : statistical error of p_tab * xs by clt (fis) = 3.256e-03 / 9.341e-03 (ave / max)
#       temp = 300.000, lad_no =   40 : statistical error of p_tab * xs by clt (rad) = 1.583e-03 / 5.531e-03 (ave / max)
#     Calculation time of energy ( 31/ 71) :7.62e+03 [eV] :  0.87 [s]
#       temp = 300.000, lad_no =   10 : statistical error of p_tab * xs by clt (tot) = 3.485e-02 / 9.933e-02 (ave / max)
#       temp = 300.000, lad_no =   20 : statistical error of p_tab * xs by clt (tot) = 2.529e-02 / 6.599e-02 (ave / max)
#       temp = 300.000, lad_no =   30 : statistical error of p_tab * xs by clt (tot) = 2.061e-02 / 4.734e-02 (ave / max)
#       temp = 300.000, lad_no =   30 : statistical error of p_tab * xs by clt (ela) = 1.636e-02 / 3.494e-02 (ave / max)
#       temp = 300.000, lad_no =   30 : statistical error of p_tab * xs by clt (fis) = 2.825e-03 / 8.614e-03 (ave / max)
#       temp = 300.000, lad_no =   30 : statistical error of p_tab * xs by clt (rad) = 2.172e-03 / 6.453e-03 (ave / max)
#     Calculation time of energy ( 32/ 71) :7.88e+03 [eV] :  0.66 [s]
#       temp = 300.000, lad_no =   10 : statistical error of p_tab * xs by clt (tot) = 3.107e-02 / 7.240e-02 (ave / max)
#       temp = 300.000, lad_no =   20 : statistical error of p_tab * xs by clt (tot) = 2.508e-02 / 6.270e-02 (ave / max)
#       temp = 300.000, lad_no =   30 : statistical error of p_tab * xs by clt (tot) = 1.975e-02 / 4.741e-02 (ave / max)
#       temp = 300.000, lad_no =   30 : statistical error of p_tab * xs by clt (ela) = 1.542e-02 / 3.241e-02 (ave / max)
#       temp = 300.000, lad_no =   30 : statistical error of p_tab * xs by clt (fis) = 3.230e-03 / 1.193e-02 (ave / max)
#       temp = 300.000, lad_no =   30 : statistical error of p_tab * xs by clt (rad) = 1.763e-03 / 4.666e-03 (ave / max)
#     Calculation time of energy ( 33/ 71) :8.12e+03 [eV] :   0.7 [s]
#       temp = 300.000, lad_no =   10 : statistical error of p_tab * xs by clt (tot) = 3.646e-02 / 6.935e-02 (ave / max)
#       temp = 300.000, lad_no =   20 : statistical error of p_tab * xs by clt (tot) = 2.383e-02 / 4.405e-02 (ave / max)
#       temp = 300.000, lad_no =   20 : statistical error of p_tab * xs by clt (ela) = 1.843e-02 / 3.059e-02 (ave / max)
#       temp = 300.000, lad_no =   20 : statistical error of p_tab * xs by clt (fis) = 4.453e-03 / 1.146e-02 (ave / max)
#       temp = 300.000, lad_no =   20 : statistical error of p_tab * xs by clt (rad) = 1.808e-03 / 4.221e-03 (ave / max)
#     Calculation time of energy ( 34/ 71) :8.38e+03 [eV] :  0.48 [s]
#       temp = 300.000, lad_no =   10 : statistical error of p_tab * xs by clt (tot) = 3.152e-02 / 7.473e-02 (ave / max)
#       temp = 300.000, lad_no =   20 : statistical error of p_tab * xs by clt (tot) = 2.341e-02 / 4.409e-02 (ave / max)
#       temp = 300.000, lad_no =   20 : statistical error of p_tab * xs by clt (ela) = 1.820e-02 / 3.217e-02 (ave / max)
#       temp = 300.000, lad_no =   20 : statistical error of p_tab * xs by clt (fis) = 3.738e-03 / 9.700e-03 (ave / max)
#       temp = 300.000, lad_no =   20 : statistical error of p_tab * xs by clt (rad) = 2.114e-03 / 5.456e-03 (ave / max)
#     Calculation time of energy ( 35/ 71) :8.62e+03 [eV] :  0.49 [s]
#       temp = 300.000, lad_no =   10 : statistical error of p_tab * xs by clt (tot) = 4.044e-02 / 9.136e-02 (ave / max)
#       temp = 300.000, lad_no =   20 : statistical error of p_tab * xs by clt (tot) = 2.666e-02 / 5.523e-02 (ave / max)
#       temp = 300.000, lad_no =   30 : statistical error of p_tab * xs by clt (tot) = 2.121e-02 / 3.969e-02 (ave / max)
#       temp = 300.000, lad_no =   30 : statistical error of p_tab * xs by clt (ela) = 1.638e-02 / 2.833e-02 (ave / max)
#       temp = 300.000, lad_no =   30 : statistical error of p_tab * xs by clt (fis) = 3.670e-03 / 8.776e-03 (ave / max)
#       temp = 300.000, lad_no =   30 : statistical error of p_tab * xs by clt (rad) = 1.620e-03 / 4.155e-03 (ave / max)
#     Calculation time of energy ( 36/ 71) :8.88e+03 [eV] :  0.71 [s]
#       temp = 300.000, lad_no =   10 : statistical error of p_tab * xs by clt (tot) = 3.374e-02 / 8.471e-02 (ave / max)
#       temp = 300.000, lad_no =   20 : statistical error of p_tab * xs by clt (tot) = 2.564e-02 / 6.266e-02 (ave / max)
#       temp = 300.000, lad_no =   30 : statistical error of p_tab * xs by clt (tot) = 2.021e-02 / 4.429e-02 (ave / max)
#       temp = 300.000, lad_no =   30 : statistical error of p_tab * xs by clt (ela) = 1.609e-02 / 3.223e-02 (ave / max)
#       temp = 300.000, lad_no =   30 : statistical error of p_tab * xs by clt (fis) = 2.649e-03 / 8.191e-03 (ave / max)
#       temp = 300.000, lad_no =   30 : statistical error of p_tab * xs by clt (rad) = 1.761e-03 / 5.046e-03 (ave / max)
#     Calculation time of energy ( 37/ 71) :9.12e+03 [eV] :  0.74 [s]
#       temp = 300.000, lad_no =   10 : statistical error of p_tab * xs by clt (tot) = 3.336e-02 / 5.649e-02 (ave / max)
#       temp = 300.000, lad_no =   20 : statistical error of p_tab * xs by clt (tot) = 2.450e-02 / 4.644e-02 (ave / max)
#       temp = 300.000, lad_no =   20 : statistical error of p_tab * xs by clt (ela) = 1.951e-02 / 3.451e-02 (ave / max)
#       temp = 300.000, lad_no =   20 : statistical error of p_tab * xs by clt (fis) = 3.244e-03 / 8.136e-03 (ave / max)
#       temp = 300.000, lad_no =   20 : statistical error of p_tab * xs by clt (rad) = 2.069e-03 / 5.174e-03 (ave / max)
#     Calculation time of energy ( 38/ 71) :9.38e+03 [eV] :  0.48 [s]
#       temp = 300.000, lad_no =   10 : statistical error of p_tab * xs by clt (tot) = 3.531e-02 / 7.889e-02 (ave / max)
#       temp = 300.000, lad_no =   20 : statistical error of p_tab * xs by clt (tot) = 2.385e-02 / 4.380e-02 (ave / max)
#       temp = 300.000, lad_no =   20 : statistical error of p_tab * xs by clt (ela) = 1.853e-02 / 3.191e-02 (ave / max)
#       temp = 300.000, lad_no =   20 : statistical error of p_tab * xs by clt (fis) = 3.818e-03 / 8.525e-03 (ave / max)
#       temp = 300.000, lad_no =   20 : statistical error of p_tab * xs by clt (rad) = 1.798e-03 / 3.988e-03 (ave / max)
#     Calculation time of energy ( 39/ 71) :9.62e+03 [eV] :  0.48 [s]
#       temp = 300.000, lad_no =   10 : statistical error of p_tab * xs by clt (tot) = 3.560e-02 / 7.176e-02 (ave / max)
#       temp = 300.000, lad_no =   20 : statistical error of p_tab * xs by clt (tot) = 2.551e-02 / 5.415e-02 (ave / max)
#       temp = 300.000, lad_no =   30 : statistical error of p_tab * xs by clt (tot) = 2.102e-02 / 4.193e-02 (ave / max)
#       temp = 300.000, lad_no =   30 : statistical error of p_tab * xs by clt (ela) = 1.672e-02 / 3.119e-02 (ave / max)
#       temp = 300.000, lad_no =   30 : statistical error of p_tab * xs by clt (fis) = 2.714e-03 / 7.124e-03 (ave / max)
#       temp = 300.000, lad_no =   30 : statistical error of p_tab * xs by clt (rad) = 1.734e-03 / 4.210e-03 (ave / max)
#     Calculation time of energy ( 40/ 71) :9.88e+03 [eV] :  0.75 [s]
#       temp = 300.000, lad_no =   10 : statistical error of p_tab * xs by clt (tot) = 3.190e-02 / 7.074e-02 (ave / max)
#       temp = 300.000, lad_no =   20 : statistical error of p_tab * xs by clt (tot) = 2.447e-02 / 5.451e-02 (ave / max)
#       temp = 300.000, lad_no =   30 : statistical error of p_tab * xs by clt (tot) = 2.005e-02 / 4.281e-02 (ave / max)
#       temp = 300.000, lad_no =   30 : statistical error of p_tab * xs by clt (ela) = 1.590e-02 / 3.181e-02 (ave / max)
#       temp = 300.000, lad_no =   30 : statistical error of p_tab * xs by clt (fis) = 2.770e-03 / 7.599e-03 (ave / max)
#       temp = 300.000, lad_no =   30 : statistical error of p_tab * xs by clt (rad) = 1.620e-03 / 4.253e-03 (ave / max)
#     Calculation time of energy ( 41/ 71) :1.02e+04 [eV] :  0.76 [s]
#       temp = 300.000, lad_no =   10 : statistical error of p_tab * xs by clt (tot) = 3.359e-02 / 5.423e-02 (ave / max)
#       temp = 300.000, lad_no =   20 : statistical error of p_tab * xs by clt (tot) = 2.571e-02 / 4.875e-02 (ave / max)
#       temp = 300.000, lad_no =   20 : statistical error of p_tab * xs by clt (ela) = 2.037e-02 / 3.536e-02 (ave / max)
#       temp = 300.000, lad_no =   20 : statistical error of p_tab * xs by clt (fis) = 3.589e-03 / 9.211e-03 (ave / max)
#       temp = 300.000, lad_no =   20 : statistical error of p_tab * xs by clt (rad) = 1.938e-03 / 4.414e-03 (ave / max)
# ...
#     3041 / 3167 : 6.36880000e-04 : 6.45000000e-03  2.81998800e+00  2.82643800e+00 -> 2.82643800e+00
#     3042 / 3167 : 6.37270000e-04 : 6.45000000e-03  2.81597100e+00  2.82242100e+00 -> 2.82242100e+00
#     3043 / 3167 : 6.37617000e-04 : 6.45000000e-03  2.81901400e+00  2.82546400e+00 -> 2.82546400e+00
#     3044 / 3167 : 6.37876000e-04 : 6.45000000e-03  2.82863900e+00  2.83508900e+00 -> 2.83508900e+00
#     3045 / 3167 : 6.38050000e-04 : 6.45000000e-03  2.84215400e+00  2.84860400e+00 -> 2.84860400e+00
#     3046 / 3167 : 6.38310000e-04 : 6.45000000e-03  2.86927200e+00  2.87572200e+00 -> 2.87572200e+00
#     3047 / 3167 : 6.38483000e-04 : 6.45000000e-03  2.88091100e+00  2.88736100e+00 -> 2.88736100e+00
#     3048 / 3167 : 6.38656000e-04 : 6.45000000e-03  2.88465200e+00  2.89110200e+00 -> 2.89110200e+00
#     3049 / 3167 : 6.38873000e-04 : 6.45000000e-03  2.88089300e+00  2.88734300e+00 -> 2.88734300e+00
#     3050 / 3167 : 6.39067000e-04 : 6.45000000e-03  2.86793900e+00  2.87438900e+00 -> 2.87438900e+00
#     3051 / 3167 : 6.39478000e-04 : 6.45000000e-03  2.82354100e+00  2.82999100e+00 -> 2.82999100e+00
#     3052 / 3167 : 6.39690000e-04 : 6.45000000e-03  2.81031700e+00  2.81676700e+00 -> 2.81676700e+00
#     3053 / 3167 : 6.39952000e-04 : 6.45000000e-03  2.80474300e+00  2.81119300e+00 -> 2.81119300e+00
#     3054 / 3167 : 6.40214000e-04 : 6.45000000e-03  2.80807600e+00  2.81452600e+00 -> 2.81452600e+00
#     3055 / 3167 : 6.40345000e-04 : 6.45000000e-03  2.81361100e+00  2.82006100e+00 -> 2.82006100e+00
#     3056 / 3167 : 6.40476000e-04 : 6.45000000e-03  2.82271700e+00  2.82916700e+00 -> 2.82916700e+00
#     3057 / 3167 : 6.40607000e-04 : 6.45000000e-03  2.83593200e+00  2.84238200e+00 -> 2.84238200e+00
#     3058 / 3167 : 6.40934000e-04 : 6.45000000e-03  2.87504800e+00  2.88149800e+00 -> 2.88149800e+00
#     3059 / 3167 : 6.41130000e-04 : 6.45000000e-03  2.88727600e+00  2.89372600e+00 -> 2.89372600e+00
#     3060 / 3167 : 6.41326000e-04 : 6.45000000e-03  2.89026900e+00  2.89671900e+00 -> 2.89671900e+00
#     3061 / 3167 : 6.41638000e-04 : 6.45000000e-03  2.88530400e+00  2.89175400e+00 -> 2.89175400e+00
#     3062 / 3167 : 6.41992000e-04 : 6.45000000e-03  2.86785200e+00  2.87430200e+00 -> 2.87430200e+00
#     3063 / 3167 : 6.42317000e-04 : 6.45000000e-03  2.85066000e+00  2.85711000e+00 -> 2.85711000e+00
#     3064 / 3167 : 6.42534000e-04 : 6.45000000e-03  2.84536600e+00  2.85181600e+00 -> 2.85181600e+00
#     3065 / 3167 : 6.42752000e-04 : 6.45000000e-03  2.84644400e+00  2.85289400e+00 -> 2.85289400e+00
#     3066 / 3167 : 6.42969000e-04 : 6.45000000e-03  2.85392500e+00  2.86037500e+00 -> 2.86037500e+00
#     3067 / 3167 : 6.43512000e-04 : 6.45000000e-03  2.88585100e+00  2.89230100e+00 -> 2.89230100e+00
#     3068 / 3167 : 6.43838000e-04 : 6.45000000e-03  2.89411000e+00  2.90056000e+00 -> 2.90056000e+00
#     3069 / 3167 : 6.44055000e-04 : 6.45000000e-03  2.89501900e+00  2.90146900e+00 -> 2.90146900e+00
#     3070 / 3167 : 6.44517000e-04 : 6.45000000e-03  2.89082200e+00  2.89727200e+00 -> 2.89727200e+00
#     3071 / 3167 : 6.44734000e-04 : 6.45000000e-03  2.88043100e+00  2.88688100e+00 -> 2.88688100e+00
#     3072 / 3167 : 6.44914000e-04 : 6.45000000e-03  2.86083500e+00  2.86728500e+00 -> 2.86728500e+00
#     3073 / 3167 : 6.45269000e-04 : 6.45000000e-03  2.80572500e+00  2.81217500e+00 -> 2.81217500e+00
#     3074 / 3167 : 6.45425000e-04 : 6.45000000e-03  2.78905000e+00  2.79550000e+00 -> 2.79550000e+00
#     3075 / 3167 : 6.45581000e-04 : 6.45000000e-03  2.78065400e+00  2.78710400e+00 -> 2.78710400e+00
#     3076 / 3167 : 6.45685000e-04 : 6.45000000e-03  2.77947700e+00  2.78592700e+00 -> 2.78592700e+00
#     3077 / 3167 : 6.45790000e-04 : 6.45000000e-03  2.78177200e+00  2.78822200e+00 -> 2.78822200e+00
#     3078 / 3167 : 6.45894000e-04 : 6.45000000e-03  2.78762600e+00  2.79407600e+00 -> 2.79407600e+00
#     3079 / 3167 : 6.46050000e-04 : 6.45000000e-03  2.80327500e+00  2.80972500e+00 -> 2.80972500e+00
#     3080 / 3167 : 6.46389000e-04 : 6.45000000e-03  2.85199500e+00  2.85844500e+00 -> 2.85844500e+00
#     3081 / 3167 : 6.46532000e-04 : 6.45000000e-03  2.86357500e+00  2.87002500e+00 -> 2.87002500e+00
#     3082 / 3167 : 6.46623000e-04 : 6.45000000e-03  2.86542000e+00  2.87187000e+00 -> 2.87187000e+00
#     3083 / 3167 : 6.46846000e-04 : 6.45000000e-03  2.85846000e+00  2.86491000e+00 -> 2.86491000e+00
#     3084 / 3167 : 6.47196000e-04 : 6.45000000e-03  2.84446900e+00  2.85091900e+00 -> 2.85091900e+00
#     3085 / 3167 : 6.47404000e-04 : 6.45000000e-03  2.84248600e+00  2.84893600e+00 -> 2.84893600e+00
#     3086 / 3167 : 6.47612000e-04 : 6.45000000e-03  2.84621600e+00  2.85266600e+00 -> 2.85266600e+00
#     3087 / 3167 : 6.47923000e-04 : 6.45000000e-03  2.86218500e+00  2.86863500e+00 -> 2.86863500e+00
#     3088 / 3167 : 6.48131000e-04 : 6.45000000e-03  2.87615800e+00  2.88260800e+00 -> 2.88260800e+00
#     3089 / 3167 : 6.48338000e-04 : 6.45000000e-03  2.88695000e+00  2.89340000e+00 -> 2.89340000e+00
#     3090 / 3167 : 6.48754000e-04 : 6.45000000e-03  2.89400300e+00  2.90045300e+00 -> 2.90045300e+00
#     3091 / 3167 : 6.50000000e-04 : 6.45000000e-03  2.88770000e+00  2.89415000e+00 -> 2.89415000e+00
#     3092 / 3167 : 1.00000000e-03 : 6.45000000e-03  2.88780000e+00  2.89425000e+00 -> 2.89425000e+00
#     3093 / 3167 : 2.00000000e-03 : 6.45000000e-03  2.88783200e+00  2.89428200e+00 -> 2.89428200e+00
#     3094 / 3167 : 3.00000000e-03 : 6.45000000e-03  2.88786500e+00  2.89431500e+00 -> 2.89431500e+00
#     3095 / 3167 : 4.00000000e-03 : 6.45000000e-03  2.88789700e+00  2.89434700e+00 -> 2.89434700e+00
#     3096 / 3167 : 5.00000000e-03 : 6.45000000e-03  2.88792900e+00  2.89437900e+00 -> 2.89437900e+00
#     3097 / 3167 : 6.00000000e-03 : 6.45000000e-03  2.88796200e+00  2.89441200e+00 -> 2.89441200e+00
#     3098 / 3167 : 7.00000000e-03 : 6.45000000e-03  2.88799400e+00  2.89444400e+00 -> 2.89444400e+00
#     3099 / 3167 : 8.00000000e-03 : 6.45000000e-03  2.88802600e+00  2.89447600e+00 -> 2.89447600e+00
#     3100 / 3167 : 9.00000000e-03 : 6.45000000e-03  2.88805900e+00  2.89450900e+00 -> 2.89450900e+00
#     3101 / 3167 : 1.00000000e-02 : 6.45000000e-03  2.88809100e+00  2.89454100e+00 -> 2.89454100e+00
#     3102 / 3167 : 1.50000000e-02 : 6.45000000e-03  2.88825300e+00  2.89470300e+00 -> 2.89470300e+00
#     3103 / 3167 : 2.00000000e-02 : 6.45000000e-03  2.88841400e+00  2.89486400e+00 -> 2.89486400e+00
#     3104 / 3167 : 3.00000000e-02 : 6.45000000e-03  2.88873700e+00  2.89518700e+00 -> 2.89518700e+00
#     3105 / 3167 : 4.00000000e-02 : 6.45000000e-03  2.88906100e+00  2.89551100e+00 -> 2.89551100e+00
#     3106 / 3167 : 5.00000000e-02 : 6.45000000e-03  2.88938400e+00  2.89583400e+00 -> 2.89583400e+00
#     3107 / 3167 : 6.00000000e-02 : 6.45000000e-03  2.88950500e+00  2.89595500e+00 -> 2.89595500e+00
#     3108 / 3167 : 7.00000000e-02 : 6.45000000e-03  2.88962500e+00  2.89607500e+00 -> 2.89607500e+00
#     3109 / 3167 : 8.00000000e-02 : 6.45000000e-03  2.88974700e+00  2.89619700e+00 -> 2.89619700e+00
#     3110 / 3167 : 9.00000000e-02 : 6.45000000e-03  2.88986800e+00  2.89631800e+00 -> 2.89631800e+00
#     3111 / 3167 : 1.00000000e-01 : 6.45000000e-03  2.88854300e+00  2.89499300e+00 -> 2.89499300e+00
#     3112 / 3167 : 1.50000000e-01 : 6.45000000e-03  2.89088000e+00  2.89733000e+00 -> 2.89733000e+00
#     3113 / 3167 : 2.00000000e-01 : 6.45000000e-03  2.89637800e+00  2.90282800e+00 -> 2.90282800e+00
#     3114 / 3167 : 2.50000000e-01 : 6.45000000e-03  2.90206500e+00  2.90851500e+00 -> 2.90851500e+00
#     3115 / 3167 : 3.00000000e-01 : 6.45000000e-03  2.90793700e+00  2.91438700e+00 -> 2.91438700e+00
#     3116 / 3167 : 3.50000000e-01 : 6.45000000e-03  2.91399000e+00  2.92044000e+00 -> 2.92044000e+00
#     3117 / 3167 : 4.00000000e-01 : 6.45000000e-03  2.92021900e+00  2.92666900e+00 -> 2.92666900e+00
#     3118 / 3167 : 5.00000000e-01 : 6.45000000e-03  2.93318700e+00  2.93963700e+00 -> 2.93963700e+00
#     3119 / 3167 : 6.00000000e-01 : 6.45000000e-03  2.94754400e+00  2.95399400e+00 -> 2.95399400e+00
#     3120 / 3167 : 7.00000000e-01 : 6.45000000e-03  2.96178200e+00  2.96823200e+00 -> 2.96823200e+00
#     3121 / 3167 : 8.00000000e-01 : 6.45000000e-03  2.97660100e+00  2.98305100e+00 -> 2.98305100e+00
#     3122 / 3167 : 9.00000000e-01 : 6.45000000e-03  2.99166500e+00  2.99811500e+00 -> 2.99811500e+00
#     3123 / 3167 : 1.00000000e+00 : 6.45000000e-03  3.00648300e+00  3.01293300e+00 -> 3.01293300e+00
#     3124 / 3167 : 1.20000000e+00 : 6.45000000e-03  3.03777200e+00  3.04422200e+00 -> 3.04422200e+00
#     3125 / 3167 : 1.40000000e+00 : 6.45000000e-03  3.07098400e+00  3.07743400e+00 -> 3.07743400e+00
#     3126 / 3167 : 1.60000000e+00 : 6.45000000e-03  3.10617300e+00  3.11262300e+00 -> 3.11262300e+00
#     3127 / 3167 : 1.80000000e+00 : 6.45000000e-03  3.13918100e+00  3.14563100e+00 -> 3.14563100e+00
#     3128 / 3167 : 2.00000000e+00 : 6.45000000e-03  3.16903100e+00  3.17548100e+00 -> 3.17548100e+00
#     3129 / 3167 : 2.20000000e+00 : 6.45000000e-03  3.19580600e+00  3.20225600e+00 -> 3.20225600e+00
#     3130 / 3167 : 2.40000000e+00 : 6.45000000e-03  3.22191300e+00  3.22836300e+00 -> 3.22836300e+00
#     3131 / 3167 : 2.60000000e+00 : 6.45000000e-03  3.25033700e+00  3.25678700e+00 -> 3.25678700e+00
#     3132 / 3167 : 2.80000000e+00 : 6.45000000e-03  3.28059500e+00  3.28704500e+00 -> 3.28704500e+00
#     3133 / 3167 : 3.00000000e+00 : 6.45000000e-03  3.31182400e+00  3.31827400e+00 -> 3.31827400e+00
#     3134 / 3167 : 3.50000000e+00 : 6.45000000e-03  3.37324900e+00  3.37969900e+00 -> 3.37969900e+00
#     3135 / 3167 : 4.00000000e+00 : 6.45000000e-03  3.44697800e+00  3.45342800e+00 -> 3.45342800e+00
#     3136 / 3167 : 4.50000000e+00 : 6.09166667e-03  3.52432100e+00  3.53041300e+00 -> 3.53041267e+00  ***
#     3137 / 3167 : 5.00000000e+00 : 5.73333333e-03  3.60464100e+00  3.61037400e+00 -> 3.61037433e+00  ***
#     3138 / 3167 : 5.50000000e+00 : 5.37500000e-03  3.68059100e+00  3.68596600e+00 -> 3.68596600e+00
#     3139 / 3167 : 6.00000000e+00 : 5.01666667e-03  3.76090400e+00  3.76592100e+00 -> 3.76592067e+00  ***
#     3140 / 3167 : 6.50000000e+00 : 4.65833333e-03  3.84439300e+00  3.84905100e+00 -> 3.84905133e+00  ***
#     3141 / 3167 : 7.00000000e+00 : 4.30000000e-03  3.92382100e+00  3.92812100e+00 -> 3.92812100e+00
#     3142 / 3167 : 7.50000000e+00 : 4.30000000e-03  3.99818500e+00  4.00248500e+00 -> 4.00248500e+00
#     3143 / 3167 : 8.00000000e+00 : 4.30000000e-03  4.07095300e+00  4.07525300e+00 -> 4.07525300e+00
#     3144 / 3167 : 8.50000000e+00 : 4.30000000e-03  4.14911300e+00  4.15341300e+00 -> 4.15341300e+00
#     3145 / 3167 : 9.00000000e+00 : 4.30000000e-03  4.22952500e+00  4.23382500e+00 -> 4.23382500e+00
#     3146 / 3167 : 9.50000000e+00 : 4.30000000e-03  4.30863000e+00  4.31293000e+00 -> 4.31293000e+00
#     3147 / 3167 : 1.00000000e+01 : 4.30000000e-03  4.38369600e+00  4.38799600e+00 -> 4.38799600e+00
#     3148 / 3167 : 1.05000000e+01 : 4.30000000e-03  4.45371800e+00  4.45801800e+00 -> 4.45801800e+00
#     3149 / 3167 : 1.10000000e+01 : 4.30000000e-03  4.52079000e+00  4.52509000e+00 -> 4.52509000e+00
#     3150 / 3167 : 1.15000000e+01 : 4.30000000e-03  4.58696300e+00  4.59126300e+00 -> 4.59126300e+00
#     3151 / 3167 : 1.20000000e+01 : 4.30000000e-03  4.65390100e+00  4.65820100e+00 -> 4.65820100e+00
#     3152 / 3167 : 1.25000000e+01 : 4.30000000e-03  4.72445200e+00  4.72875200e+00 -> 4.72875200e+00
#     3153 / 3167 : 1.30000000e+01 : 4.30000000e-03  4.79589400e+00  4.80019400e+00 -> 4.80019400e+00
#     3154 / 3167 : 1.35000000e+01 : 4.30000000e-03  4.86487600e+00  4.86917600e+00 -> 4.86917600e+00
#     3155 / 3167 : 1.40000000e+01 : 4.30000000e-03  4.93248100e+00  4.93678100e+00 -> 4.93678100e+00
#     3156 / 3167 : 1.45000000e+01 : 4.30000000e-03  4.99899800e+00  5.00329800e+00 -> 5.00329800e+00
#     3157 / 3167 : 1.50000000e+01 : 4.30000000e-03  5.06502600e+00  5.06932600e+00 -> 5.06932600e+00
#     3158 / 3167 : 1.55000000e+01 : 4.30000000e-03  5.13089100e+00  5.13519100e+00 -> 5.13519100e+00
#     3159 / 3167 : 1.60000000e+01 : 4.30000000e-03  5.19643900e+00  5.20073900e+00 -> 5.20073900e+00
#     3160 / 3167 : 1.65000000e+01 : 4.30000000e-03  5.26153800e+00  5.26583800e+00 -> 5.26583800e+00
#     3161 / 3167 : 1.70000000e+01 : 4.30000000e-03  5.32607700e+00  5.33037700e+00 -> 5.33037700e+00
#     3162 / 3167 : 1.75000000e+01 : 4.30000000e-03  5.38996000e+00  5.39426000e+00 -> 5.39426000e+00
#     3163 / 3167 : 1.80000000e+01 : 4.30000000e-03  5.45310100e+00  5.45740100e+00 -> 5.45740100e+00
#     3164 / 3167 : 1.85000000e+01 : 4.30000000e-03  5.51542900e+00  5.51972900e+00 -> 5.51972900e+00
#     3165 / 3167 : 1.90000000e+01 : 4.30000000e-03  5.57688100e+00  5.58118100e+00 -> 5.58118100e+00
#     3166 / 3167 : 1.95000000e+01 : 4.30000000e-03  5.63740200e+00  5.64170200e+00 -> 5.64170200e+00
#     3167 / 3167 : 2.00000000e+01 : 4.30000000e-03  5.69694900e+00  5.70124900e+00 -> 5.70124900e+00
#
#
# =====================
# =                   =
# =  --- CAUTION ---  =
# =                   =
# =====================
#
#   <Class name>
#     FastAceDataGenerator
#
#   <Function name>
#     modify_delayed_neutron_data
#
#   <Warning message>
#     Position                           : 1
#     Lowest delayed neutron energy grid : 10000
#     The lowest delayed neutron energy grid is larger than 40.0 eV.
#     This delayed neutron energy grid may not be appropriate.
#
#
# =====================
# =                   =
# =  --- CAUTION ---  =
# =                   =
# =====================
#
#   <Class name>
#     FastAceDataGenerator
#
#   <Function name>
#     modify_delayed_neutron_data
#
#   <Warning message>
#     Position                           : 2
#     Lowest delayed neutron energy grid : 10000
#     The lowest delayed neutron energy grid is larger than 40.0 eV.
#     This delayed neutron energy grid may not be appropriate.
#
#
# =====================
# =                   =
# =  --- CAUTION ---  =
# =                   =
# =====================
#
#   <Class name>
#     FastAceDataGenerator
#
#   <Function name>
#     modify_delayed_neutron_data
#
#   <Warning message>
#     Position                           : 3
#     Lowest delayed neutron energy grid : 10000
#     The lowest delayed neutron energy grid is larger than 40.0 eV.
#     This delayed neutron energy grid may not be appropriate.
#
#
# =====================
# =                   =
# =  --- CAUTION ---  =
# =                   =
# =====================
#
#   <Class name>
#     FastAceDataGenerator
#
#   <Function name>
#     modify_delayed_neutron_data
#
#   <Warning message>
#     Position                           : 4
#     Lowest delayed neutron energy grid : 10000
#     The lowest delayed neutron energy grid is larger than 40.0 eV.
#     This delayed neutron energy grid may not be appropriate.
#
#
# =====================
# =                   =
# =  --- CAUTION ---  =
# =                   =
# =====================
#
#   <Class name>
#     FastAceDataGenerator
#
#   <Function name>
#     modify_delayed_neutron_data
#
#   <Warning message>
#     Position                           : 5
#     Lowest delayed neutron energy grid : 10000
#     The lowest delayed neutron energy grid is larger than 40.0 eV.
#     This delayed neutron energy grid may not be appropriate.
#
#
# =====================
# =                   =
# =  --- CAUTION ---  =
# =                   =
# =====================
#
#   <Class name>
#     FastAceDataGenerator
#
#   <Function name>
#     modify_delayed_neutron_data
#
#   <Warning message>
#     Position                           : 6
#     Lowest delayed neutron energy grid : 10000
#     The lowest delayed neutron energy grid is larger than 40.0 eV.
#     This delayed neutron energy grid may not be appropriate.
#
# Total calculation time : 1.6000000e+02 [s]
#
# ***********************************************************************************************
#
#
# Finish all calculation.
# FRENDY calculation date : 2026/04/05 23:02:53
#
# /////////////////////////////////////////////////////////////////////////////////////////
#
# FRENDY CALCULATION STATUS: NORMAL TERMINATION ( input: /mnt/c/Users/jacob/frendy_20241030/frendy/main/Pu239_acegenerator_upgrade.dat )
#
# Intermediate Files Removed
#
#
# ACE file successfully generated. The path to it is: /mnt/c/Users/jacob/frendy_20241030/frendy/main/Pu239_upgrade.ace

# %% [markdown]
# Next we will create our direct perturbation ACE files. We will apply a perturbation of +10% to the fission cross section.

# %%
WINDIGO.generate_direct_perturbation_ace_files(
        frendy_Path="/mnt/c/Users/jacob/frendy_20241030",
        unperturbed_ACE_file_path=unperturbed_pu239_path,
        energy_grid=scale44_grid_MeV,
        mt_Number=18,
        nuclide="Pu239",
        perturbation_coefficient=1.10,
        cleanup_Flag=True
)
# Out:
# Intermediate Files Removed
# All ACE files have successfully generated; they are located in: /mnt/c/Users/jacob/frendy_20241030/Pu239_DirectPerturbationACEFiles_ReactionMT_18
# '/mnt/c/Users/jacob/frendy_20241030/Pu239_DirectPerturbationACEFiles_ReactionMT_18'

# %% [markdown]
# To generate our random sampling ACE files, we need to use Sandy to first retrieve a relative covariance matrix for Pu-239's fission cross section.

# %%
pu239_fission_relative_covariance_data_path, pu239_fission_relative_covariance_plot_path = WINDIGO.sandy_covariance_retrieval(
    energy_grid=scale44_grid_eV,
    nuclide="Pu239",
    mt_Number=18,
    data_library="endfb_80",
    temperature=300,
    relative_Flag=True,
    plotting_Flag=True
)
# Out:
#  njoy 2016.78  03Feb25                                       04/05/26 23:07:17
#  *****************************************************************************
#
#  moder...                                                                 0.0s
#
#  reconr...                                                                0.3s
#
#  ---message from rdf2bw---calculation of angular distribution not installed.
#
#  broadr...                                                                0.8s
#
#  thermr...                                                                0.9s
#
#  wrote thermal data for temp = 3.0000E+02                                 0.9s
#
#  heatr...                                                                 0.9s
#
#  ---message from hinit---mf6, mt 16 does not give recoil za= 94238
#                           one-particle recoil approx. used.
#
#  ---message from hinit---mf6, mt 17 does not give recoil za= 94237
#                           one-particle recoil approx. used.
#
#  ---message from hinit---mf6, mt 37 does not give recoil za= 94236
#                           one-particle recoil approx. used.
#
#  ---message from hinit---mf6, mt 91 does not give recoil za= 94239
#                           one-particle recoil approx. used.
#
#  ---message from hinit---mf6, mt102 does not give recoil za= 94240
#                           photon momentum recoil used.
#
#  ---message from nheat---changed q from   1.985785E+08 to   1.880954E+08
#                           for mt  18 by taking out delayed components
#
#  heatr...                                                                 1.2s
#
#  ---message from hinit---mf6, mt 16 does not give recoil za= 94238
#                           one-particle recoil approx. used.
#
#  ---message from hinit---mf6, mt 17 does not give recoil za= 94237
#                           one-particle recoil approx. used.
#
#  ---message from hinit---mf6, mt 37 does not give recoil za= 94236
#                           one-particle recoil approx. used.
#
#  ---message from hinit---mf6, mt 91 does not give recoil za= 94239
#                           one-particle recoil approx. used.
#
#  ---message from hinit---mf6, mt102 does not give recoil za= 94240
#                           photon momentum recoil used.
#
#  ---message from nheat---changed q from   1.985785E+08 to   1.880954E+08
#                           for mt  18 by taking out delayed components
#
#  gaspr...                                                                 1.5s
#
#  purr...                                                                  1.5s
#
#  mat = 9437                                                               1.5s
#
#  ---message from purr---total xs less than its components at e=  2.5000E+03
#                           check evaluation file
#
#  ---message from purr---total xs less than its components at e=  2.5500E+03
#                           check evaluation file
#
#  ---message from purr---total xs less than its components at e=  2.6500E+03
#                           check evaluation file
#
#  ---message from purr---total xs less than its components at e=  2.7500E+03
#                           check evaluation file
#
#  ---message from purr---total xs less than its components at e=  2.8500E+03
#                           check evaluation file
#
#  ---message from purr---total xs less than its components at e=  2.9500E+03
#                           check evaluation file
#
#  ---message from purr---total xs less than its components at e=  3.0500E+03
#                           check evaluation file
#
#  ---message from purr---total xs less than its components at e=  3.1500E+03
#                           check evaluation file
#
#  ---message from purr---total xs less than its components at e=  3.2500E+03
#                           check evaluation file
#
#  ---message from purr---total xs less than its components at e=  3.3500E+03
#                           check evaluation file
#
#  ---message from purr---total xs less than its components at e=  3.4500E+03
#                           check evaluation file
#
#  ---message from purr---total xs less than its components at e=  3.5500E+03
#                           check evaluation file
#
#  ---message from purr---total xs less than its components at e=  3.6500E+03
#                           check evaluation file
#
#  ---message from purr---total xs less than its components at e=  4.6250E+03
#                           check evaluation file
#
#  ---message from purr---total xs less than its components at e=  4.8750E+03
#                           check evaluation file
#
#  ---message from purr---total xs less than its components at e=  5.1250E+03
#                           check evaluation file
#
#  ---message from purr---total xs less than its components at e=  5.3750E+03
#                           check evaluation file
#
#  ---message from purr---total xs less than its components at e=  5.6250E+03
#                           check evaluation file
#
#  ---message from purr---total xs less than its components at e=  5.8750E+03
#                           check evaluation file
#
#  ---message from purr---total xs less than its components at e=  6.1250E+03
#                           check evaluation file
#
#  ---message from purr---total xs less than its components at e=  6.3750E+03
#                           check evaluation file
#
#  ---message from purr---total xs less than its components at e=  6.6250E+03
#                           check evaluation file
#
#  ---message from purr---total xs less than its components at e=  6.8750E+03
#                           check evaluation file
#       1 of    71 loops done for all temps & sig0s.                        3.2s
#       2 of    71 loops done for all temps & sig0s.                        4.8s
#       3 of    71 loops done for all temps & sig0s.                        6.4s
#       4 of    71 loops done for all temps & sig0s.                        8.0s
#       5 of    71 loops done for all temps & sig0s.                        9.5s
#       6 of    71 loops done for all temps & sig0s.                       11.2s
#       7 of    71 loops done for all temps & sig0s.                       12.8s
#       8 of    71 loops done for all temps & sig0s.                       14.4s
#       9 of    71 loops done for all temps & sig0s.                       16.0s
#      10 of    71 loops done for all temps & sig0s.                       17.6s
#      11 of    71 loops done for all temps & sig0s.                       19.2s
#      12 of    71 loops done for all temps & sig0s.                       20.9s
#      13 of    71 loops done for all temps & sig0s.                       22.5s
#      14 of    71 loops done for all temps & sig0s.                       24.2s
#      15 of    71 loops done for all temps & sig0s.                       25.8s
#      16 of    71 loops done for all temps & sig0s.                       27.5s
#      17 of    71 loops done for all temps & sig0s.                       29.2s
#      18 of    71 loops done for all temps & sig0s.                       30.8s
#      19 of    71 loops done for all temps & sig0s.                       32.5s
#      20 of    71 loops done for all temps & sig0s.                       34.2s
#      21 of    71 loops done for all temps & sig0s.                       35.8s
#      22 of    71 loops done for all temps & sig0s.                       37.5s
#      23 of    71 loops done for all temps & sig0s.                       39.2s
#      24 of    71 loops done for all temps & sig0s.                       40.9s
#      25 of    71 loops done for all temps & sig0s.                       42.6s
#      26 of    71 loops done for all temps & sig0s.                       44.3s
#      27 of    71 loops done for all temps & sig0s.                       46.0s
#      28 of    71 loops done for all temps & sig0s.                       47.7s
#      29 of    71 loops done for all temps & sig0s.                       49.3s
#      30 of    71 loops done for all temps & sig0s.                       51.0s
#      31 of    71 loops done for all temps & sig0s.                       52.7s
#      32 of    71 loops done for all temps & sig0s.                       54.5s
#      33 of    71 loops done for all temps & sig0s.                       56.1s
#      34 of    71 loops done for all temps & sig0s.                       57.9s
#      35 of    71 loops done for all temps & sig0s.                       59.6s
#      36 of    71 loops done for all temps & sig0s.                       61.3s
#      37 of    71 loops done for all temps & sig0s.                       63.1s
#      38 of    71 loops done for all temps & sig0s.                       64.8s
#      39 of    71 loops done for all temps & sig0s.                       66.5s
#      40 of    71 loops done for all temps & sig0s.                       68.2s
#      41 of    71 loops done for all temps & sig0s.                       70.1s
#      42 of    71 loops done for all temps & sig0s.                       71.9s
#      43 of    71 loops done for all temps & sig0s.                       73.6s
#      44 of    71 loops done for all temps & sig0s.                       75.5s
#      45 of    71 loops done for all temps & sig0s.                       77.2s
#      46 of    71 loops done for all temps & sig0s.                       79.0s
#      47 of    71 loops done for all temps & sig0s.                       80.7s
#      48 of    71 loops done for all temps & sig0s.                       82.4s
#      49 of    71 loops done for all temps & sig0s.                       84.2s
#      50 of    71 loops done for all temps & sig0s.                       85.9s
#      51 of    71 loops done for all temps & sig0s.                       87.7s
#      52 of    71 loops done for all temps & sig0s.                       89.4s
#      53 of    71 loops done for all temps & sig0s.                       91.2s
#      54 of    71 loops done for all temps & sig0s.                       92.9s
#      55 of    71 loops done for all temps & sig0s.                       94.7s
#      56 of    71 loops done for all temps & sig0s.                       96.4s
#      57 of    71 loops done for all temps & sig0s.                       98.2s
#      58 of    71 loops done for all temps & sig0s.                       99.9s
#      59 of    71 loops done for all temps & sig0s.                      101.7s
#      60 of    71 loops done for all temps & sig0s.                      103.5s
#      61 of    71 loops done for all temps & sig0s.                      105.2s
#      62 of    71 loops done for all temps & sig0s.                      107.0s
#      63 of    71 loops done for all temps & sig0s.                      108.8s
#      64 of    71 loops done for all temps & sig0s.                      110.6s
#      65 of    71 loops done for all temps & sig0s.                      112.4s
#      66 of    71 loops done for all temps & sig0s.                      114.1s
#      67 of    71 loops done for all temps & sig0s.                      115.9s
#      68 of    71 loops done for all temps & sig0s.                      117.7s
#      69 of    71 loops done for all temps & sig0s.                      119.5s
#      70 of    71 loops done for all temps & sig0s.                      121.3s
#      71 of    71 loops done for all temps & sig0s.                      123.1s
#
#  moder...                                                               123.1s
#
#  groupr...                                                              123.7s
#
#  ---message from conver---skipping new mf6/mt18 multiplicity section
#
#  ---message from groupr---auto finds no reactions for mf=  5
#
#  moder...                                                               123.8s
#
#  errorr...                                                              123.8s
#
#  processing mat  9437
#  ---------------------
#   94-Pu-239 LANL       EVAL-DEC17             LANL, ORNL, et al.
#
#  covariances calculated for  8 reactions and  188 groups                123.8s
#
#  Energy range :     1/    1
#
#  ---message from resprx---mf2 nls=1, but mf32 nls=0
#                           continue with partial urr covariance data
#
#  ---message from rpxlc12---include scattering radius uncertainty
# Resonance number    1(/  302)   Resonance energy -2.0000000E-02
# Resonance number    1(/  302)   Width number 1
# Resonance number    1(/  302)   Width number 2
# Resonance number    1(/  302)   Width number 3
# Resonance number    1(/  302)   Width number 4
# Resonance number    2(/  302)   Resonance energy  2.9562430E-01
# Resonance number    2(/  302)   Width number 1
# Resonance number    2(/  302)   Width number 2
# Resonance number    2(/  302)   Width number 3
# Resonance number    2(/  302)   Width number 4
# Resonance number    3(/  302)   Resonance energy  7.8158000E+00
# Resonance number    3(/  302)   Width number 1
# Resonance number    3(/  302)   Width number 2
# Resonance number    3(/  302)   Width number 3
# Resonance number    3(/  302)   Width number 4
# Resonance number    4(/  302)   Resonance energy  1.0928000E+01
# Resonance number    4(/  302)   Width number 1
# Resonance number    4(/  302)   Width number 2
# Resonance number    4(/  302)   Width number 3
# Resonance number    4(/  302)   Width number 4
# Resonance number    5(/  302)   Resonance energy  1.4678000E+01
# Resonance number    5(/  302)   Width number 1
# Resonance number    5(/  302)   Width number 2
# Resonance number    5(/  302)   Width number 3
# Resonance number    5(/  302)   Width number 4
# Resonance number    6(/  302)   Resonance energy  1.5417000E+01
# Resonance number    6(/  302)   Width number 1
# Resonance number    6(/  302)   Width number 2
# Resonance number    6(/  302)   Width number 3
# Resonance number    6(/  302)   Width number 4
# Resonance number    7(/  302)   Resonance energy  1.7657000E+01
# Resonance number    7(/  302)   Width number 1
# Resonance number    7(/  302)   Width number 2
# Resonance number    7(/  302)   Width number 3
# Resonance number    7(/  302)   Width number 4
# Resonance number    8(/  302)   Resonance energy  2.2266000E+01
# Resonance number    8(/  302)   Width number 1
# Resonance number    8(/  302)   Width number 2
# Resonance number    8(/  302)   Width number 3
# Resonance number    8(/  302)   Width number 4
# Resonance number    9(/  302)   Resonance energy  4.1457000E+01
# Resonance number    9(/  302)   Width number 1
# Resonance number    9(/  302)   Width number 2
# Resonance number    9(/  302)   Width number 3
# Resonance number    9(/  302)   Width number 4
# Resonance number   10(/  302)   Resonance energy  4.4531000E+01
# Resonance number   10(/  302)   Width number 1
# Resonance number   10(/  302)   Width number 2
# Resonance number   10(/  302)   Width number 3
# Resonance number   10(/  302)   Width number 4
# Resonance number   11(/  302)   Resonance energy  4.7534000E+01
# Resonance number   11(/  302)   Width number 1
# Resonance number   11(/  302)   Width number 2
# Resonance number   11(/  302)   Width number 3
# Resonance number   11(/  302)   Width number 4
# Resonance number   12(/  302)   Resonance energy  4.9576000E+01
# Resonance number   12(/  302)   Width number 1
# Resonance number   12(/  302)   Width number 2
# Resonance number   12(/  302)   Width number 3
# Resonance number   12(/  302)   Width number 4
# Resonance number   13(/  302)   Resonance energy  5.0144000E+01
# Resonance number   13(/  302)   Width number 1
# Resonance number   13(/  302)   Width number 2
# Resonance number   13(/  302)   Width number 3
# Resonance number   13(/  302)   Width number 4
# Resonance number   14(/  302)   Resonance energy  5.2648000E+01
# Resonance number   14(/  302)   Width number 1
# Resonance number   14(/  302)   Width number 2
# Resonance number   14(/  302)   Width number 3
# Resonance number   14(/  302)   Width number 4
# Resonance number   15(/  302)   Resonance energy  5.6924000E+01
# Resonance number   15(/  302)   Width number 1
# Resonance number   15(/  302)   Width number 2
# Resonance number   15(/  302)   Width number 3
# Resonance number   15(/  302)   Width number 4
# Resonance number   16(/  302)   Resonance energy  5.9291000E+01
# Resonance number   16(/  302)   Width number 1
# Resonance number   16(/  302)   Width number 2
# Resonance number   16(/  302)   Width number 3
# Resonance number   16(/  302)   Width number 4
# Resonance number   17(/  302)   Resonance energy  6.1621000E+01
# Resonance number   17(/  302)   Width number 1
# Resonance number   17(/  302)   Width number 2
# Resonance number   17(/  302)   Width number 3
# Resonance number   17(/  302)   Width number 4
# Resonance number   18(/  302)   Resonance energy  6.5454000E+01
# Resonance number   18(/  302)   Width number 1
# Resonance number   18(/  302)   Width number 2
# Resonance number   18(/  302)   Width number 3
# Resonance number   18(/  302)   Width number 4
# Resonance number   19(/  302)   Resonance energy  6.5793000E+01
# Resonance number   19(/  302)   Width number 1
# Resonance number   19(/  302)   Width number 2
# Resonance number   19(/  302)   Width number 3
# Resonance number   19(/  302)   Width number 4
# Resonance number   20(/  302)   Resonance energy  7.5034000E+01
# Resonance number   20(/  302)   Width number 1
# Resonance number   20(/  302)   Width number 2
# Resonance number   20(/  302)   Width number 3
# Resonance number   20(/  302)   Width number 4
# Resonance number   21(/  302)   Resonance energy  8.0867790E+01
# Resonance number   21(/  302)   Width number 1
# Resonance number   21(/  302)   Width number 2
# Resonance number   21(/  302)   Width number 3
# Resonance number   21(/  302)   Width number 4
# Resonance number   22(/  302)   Resonance energy  8.5360730E+01
# Resonance number   22(/  302)   Width number 1
# Resonance number   22(/  302)   Width number 2
# Resonance number   22(/  302)   Width number 3
# Resonance number   22(/  302)   Width number 4
# Resonance number   23(/  302)   Resonance energy  8.5622570E+01
# Resonance number   23(/  302)   Width number 1
# Resonance number   23(/  302)   Width number 2
# Resonance number   23(/  302)   Width number 3
# Resonance number   23(/  302)   Width number 4
# Resonance number   24(/  302)   Resonance energy  9.0854840E+01
# Resonance number   24(/  302)   Width number 1
# Resonance number   24(/  302)   Width number 2
# Resonance number   24(/  302)   Width number 3
# Resonance number   24(/  302)   Width number 4
# Resonance number   25(/  302)   Resonance energy  9.6235910E+01
# Resonance number   25(/  302)   Width number 1
# Resonance number   25(/  302)   Width number 2
# Resonance number   25(/  302)   Width number 3
# Resonance number   25(/  302)   Width number 4
# Resonance number   26(/  302)   Resonance energy  1.0025580E+02
# Resonance number   26(/  302)   Width number 1
# Resonance number   26(/  302)   Width number 2
# Resonance number   26(/  302)   Width number 3
# Resonance number   26(/  302)   Width number 4
# Resonance number   27(/  302)   Resonance energy  1.0545920E+02
# Resonance number   27(/  302)   Width number 1
# Resonance number   27(/  302)   Width number 2
# Resonance number   27(/  302)   Width number 3
# Resonance number   27(/  302)   Width number 4
# Resonance number   28(/  302)   Resonance energy  1.0683180E+02
# Resonance number   28(/  302)   Width number 1
# Resonance number   28(/  302)   Width number 2
# Resonance number   28(/  302)   Width number 3
# Resonance number   28(/  302)   Width number 4
# Resonance number   29(/  302)   Resonance energy  1.1618930E+02
# Resonance number   29(/  302)   Width number 1
# Resonance number   29(/  302)   Width number 2
# Resonance number   29(/  302)   Width number 3
# Resonance number   29(/  302)   Width number 4
# Resonance number   30(/  302)   Resonance energy  1.1900950E+02
# Resonance number   30(/  302)   Width number 1
# Resonance number   30(/  302)   Width number 2
# Resonance number   30(/  302)   Width number 3
# Resonance number   30(/  302)   Width number 4
# Resonance number   31(/  302)   Resonance energy  1.3159820E+02
# Resonance number   31(/  302)   Width number 1
# Resonance number   31(/  302)   Width number 2
# Resonance number   31(/  302)   Width number 3
# Resonance number   31(/  302)   Width number 4
# Resonance number   32(/  302)   Resonance energy  1.3398610E+02
# Resonance number   32(/  302)   Width number 1
# Resonance number   32(/  302)   Width number 2
# Resonance number   32(/  302)   Width number 3
# Resonance number   32(/  302)   Width number 4
# Resonance number   33(/  302)   Resonance energy  1.3693550E+02
# Resonance number   33(/  302)   Width number 1
# Resonance number   33(/  302)   Width number 2
# Resonance number   33(/  302)   Width number 3
# Resonance number   33(/  302)   Width number 4
# Resonance number   34(/  302)   Resonance energy  1.4647360E+02
# Resonance number   34(/  302)   Width number 1
# Resonance number   34(/  302)   Width number 2
# Resonance number   34(/  302)   Width number 3
# Resonance number   34(/  302)   Width number 4
# Resonance number   35(/  302)   Resonance energy  1.4735770E+02
# Resonance number   35(/  302)   Width number 1
# Resonance number   35(/  302)   Width number 2
# Resonance number   35(/  302)   Width number 3
# Resonance number   35(/  302)   Width number 4
# Resonance number   36(/  302)   Resonance energy  1.6471100E+02
# Resonance number   36(/  302)   Width number 1
# Resonance number   36(/  302)   Width number 2
# Resonance number   36(/  302)   Width number 3
# Resonance number   36(/  302)   Width number 4
# Resonance number   37(/  302)   Resonance energy  1.6728770E+02
# Resonance number   37(/  302)   Width number 1
# Resonance number   37(/  302)   Width number 2
# Resonance number   37(/  302)   Width number 3
# Resonance number   37(/  302)   Width number 4
# Resonance number   38(/  302)   Resonance energy  1.8462300E+02
# Resonance number   38(/  302)   Width number 1
# Resonance number   38(/  302)   Width number 2
# Resonance number   38(/  302)   Width number 3
# Resonance number   38(/  302)   Width number 4
# Resonance number   39(/  302)   Resonance energy  1.9538050E+02
# Resonance number   39(/  302)   Width number 1
# Resonance number   39(/  302)   Width number 2
# Resonance number   39(/  302)   Width number 3
# Resonance number   39(/  302)   Width number 4
# Resonance number   40(/  302)   Resonance energy  1.9961140E+02
# Resonance number   40(/  302)   Width number 1
# Resonance number   40(/  302)   Width number 2
# Resonance number   40(/  302)   Width number 3
# Resonance number   40(/  302)   Width number 4
# Resonance number   41(/  302)   Resonance energy  2.0407600E+02
# Resonance number   41(/  302)   Width number 1
# Resonance number   41(/  302)   Width number 2
# Resonance number   41(/  302)   Width number 3
# Resonance number   41(/  302)   Width number 4
# Resonance number   42(/  302)   Resonance energy  2.0759940E+02
# Resonance number   42(/  302)   Width number 1
# Resonance number   42(/  302)   Width number 2
# Resonance number   42(/  302)   Width number 3
# Resonance number   42(/  302)   Width number 4
# Resonance number   43(/  302)   Resonance energy  2.1373710E+02
# Resonance number   43(/  302)   Width number 1
# Resonance number   43(/  302)   Width number 2
# Resonance number   43(/  302)   Width number 3
# Resonance number   43(/  302)   Width number 4
# Resonance number   44(/  302)   Resonance energy  2.1677390E+02
# Resonance number   44(/  302)   Width number 1
# Resonance number   44(/  302)   Width number 2
# Resonance number   44(/  302)   Width number 3
# Resonance number   44(/  302)   Width number 4
# Resonance number   45(/  302)   Resonance energy  2.2047100E+02
# Resonance number   45(/  302)   Width number 1
# Resonance number   45(/  302)   Width number 2
# Resonance number   45(/  302)   Width number 3
# Resonance number   45(/  302)   Width number 4
# Resonance number   46(/  302)   Resonance energy  2.2625610E+02
# Resonance number   46(/  302)   Width number 1
# Resonance number   46(/  302)   Width number 2
# Resonance number   46(/  302)   Width number 3
# Resonance number   46(/  302)   Width number 4
# Resonance number   47(/  302)   Resonance energy  2.3165030E+02
# Resonance number   47(/  302)   Width number 1
# Resonance number   47(/  302)   Width number 2
# Resonance number   47(/  302)   Width number 3
# Resonance number   47(/  302)   Width number 4
# Resonance number   48(/  302)   Resonance energy  2.3405500E+02
# Resonance number   48(/  302)   Width number 1
# Resonance number   48(/  302)   Width number 2
# Resonance number   48(/  302)   Width number 3
# Resonance number   48(/  302)   Width number 4
# Resonance number   49(/  302)   Resonance energy  2.3456860E+02
# Resonance number   49(/  302)   Width number 1
# Resonance number   49(/  302)   Width number 2
# Resonance number   49(/  302)   Width number 3
# Resonance number   49(/  302)   Width number 4
# Resonance number   50(/  302)   Resonance energy  2.4314330E+02
# Resonance number   50(/  302)   Width number 1
# Resonance number   50(/  302)   Width number 2
# Resonance number   50(/  302)   Width number 3
# Resonance number   50(/  302)   Width number 4
# Resonance number   51(/  302)   Resonance energy  2.4912500E+02
# Resonance number   51(/  302)   Width number 1
# Resonance number   51(/  302)   Width number 2
# Resonance number   51(/  302)   Width number 3
# Resonance number   51(/  302)   Width number 4
# Resonance number   52(/  302)   Resonance energy  2.5149590E+02
# Resonance number   52(/  302)   Width number 1
# Resonance number   52(/  302)   Width number 2
# Resonance number   52(/  302)   Width number 3
# Resonance number   52(/  302)   Width number 4
# Resonance number   53(/  302)   Resonance energy  2.6227010E+02
# Resonance number   53(/  302)   Width number 1
# Resonance number   53(/  302)   Width number 2
# Resonance number   53(/  302)   Width number 3
# Resonance number   53(/  302)   Width number 4
# Resonance number   54(/  302)   Resonance energy  2.7291320E+02
# Resonance number   54(/  302)   Width number 1
# Resonance number   54(/  302)   Width number 2
# Resonance number   54(/  302)   Width number 3
# Resonance number   54(/  302)   Width number 4
# Resonance number   55(/  302)   Resonance energy  2.7510730E+02
# Resonance number   55(/  302)   Width number 1
# Resonance number   55(/  302)   Width number 2
# Resonance number   55(/  302)   Width number 3
# Resonance number   55(/  302)   Width number 4
# Resonance number   56(/  302)   Resonance energy  2.7588390E+02
# Resonance number   56(/  302)   Width number 1
# Resonance number   56(/  302)   Width number 2
# Resonance number   56(/  302)   Width number 3
# Resonance number   56(/  302)   Width number 4
# Resonance number   57(/  302)   Resonance energy  2.7616310E+02
# Resonance number   57(/  302)   Width number 1
# Resonance number   57(/  302)   Width number 2
# Resonance number   57(/  302)   Width number 3
# Resonance number   57(/  302)   Width number 4
# Resonance number   58(/  302)   Resonance energy  2.7985950E+02
# Resonance number   58(/  302)   Width number 1
# Resonance number   58(/  302)   Width number 2
# Resonance number   58(/  302)   Width number 3
# Resonance number   58(/  302)   Width number 4
# Resonance number   59(/  302)   Resonance energy  2.8322070E+02
# Resonance number   59(/  302)   Width number 1
# Resonance number   59(/  302)   Width number 2
# Resonance number   59(/  302)   Width number 3
# Resonance number   59(/  302)   Width number 4
# Resonance number   60(/  302)   Resonance energy  2.9083930E+02
# Resonance number   60(/  302)   Width number 1
# Resonance number   60(/  302)   Width number 2
# Resonance number   60(/  302)   Width number 3
# Resonance number   60(/  302)   Width number 4
# Resonance number   61(/  302)   Resonance energy  2.9892420E+02
# Resonance number   61(/  302)   Width number 1
# Resonance number   61(/  302)   Width number 2
# Resonance number   61(/  302)   Width number 3
# Resonance number   61(/  302)   Width number 4
# Resonance number   62(/  302)   Resonance energy  3.0215990E+02
# Resonance number   62(/  302)   Width number 1
# Resonance number   62(/  302)   Width number 2
# Resonance number   62(/  302)   Width number 3
# Resonance number   62(/  302)   Width number 4
# Resonance number   63(/  302)   Resonance energy  3.0935240E+02
# Resonance number   63(/  302)   Width number 1
# Resonance number   63(/  302)   Width number 2
# Resonance number   63(/  302)   Width number 3
# Resonance number   63(/  302)   Width number 4
# Resonance number   64(/  302)   Resonance energy  3.1397250E+02
# Resonance number   64(/  302)   Width number 1
# Resonance number   64(/  302)   Width number 2
# Resonance number   64(/  302)   Width number 3
# Resonance number   64(/  302)   Width number 4
# Resonance number   65(/  302)   Resonance energy  3.2373500E+02
# Resonance number   65(/  302)   Width number 1
# Resonance number   65(/  302)   Width number 2
# Resonance number   65(/  302)   Width number 3
# Resonance number   65(/  302)   Width number 4
# Resonance number   66(/  302)   Resonance energy  3.2413570E+02
# Resonance number   66(/  302)   Width number 1
# Resonance number   66(/  302)   Width number 2
# Resonance number   66(/  302)   Width number 3
# Resonance number   66(/  302)   Width number 4
# Resonance number   67(/  302)   Resonance energy  3.2567040E+02
# Resonance number   67(/  302)   Width number 1
# Resonance number   67(/  302)   Width number 2
# Resonance number   67(/  302)   Width number 3
# Resonance number   67(/  302)   Width number 4
# Resonance number   68(/  302)   Resonance energy  3.3631120E+02
# Resonance number   68(/  302)   Width number 1
# Resonance number   68(/  302)   Width number 2
# Resonance number   68(/  302)   Width number 3
# Resonance number   68(/  302)   Width number 4
# Resonance number   69(/  302)   Resonance energy  3.3834000E+02
# Resonance number   69(/  302)   Width number 1
# Resonance number   69(/  302)   Width number 2
# Resonance number   69(/  302)   Width number 3
# Resonance number   69(/  302)   Width number 4
# Resonance number   70(/  302)   Resonance energy  3.4358260E+02
# Resonance number   70(/  302)   Width number 1
# Resonance number   70(/  302)   Width number 2
# Resonance number   70(/  302)   Width number 3
# Resonance number   70(/  302)   Width number 4
# Resonance number   71(/  302)   Resonance energy  3.4658180E+02
# Resonance number   71(/  302)   Width number 1
# Resonance number   71(/  302)   Width number 2
# Resonance number   71(/  302)   Width number 3
# Resonance number   71(/  302)   Width number 4
# Resonance number   72(/  302)   Resonance energy  3.5070910E+02
# Resonance number   72(/  302)   Width number 1
# Resonance number   72(/  302)   Width number 2
# Resonance number   72(/  302)   Width number 3
# Resonance number   72(/  302)   Width number 4
# Resonance number   73(/  302)   Resonance energy  3.6586720E+02
# Resonance number   73(/  302)   Width number 1
# Resonance number   73(/  302)   Width number 2
# Resonance number   73(/  302)   Width number 3
# Resonance number   73(/  302)   Width number 4
# Resonance number   74(/  302)   Resonance energy  4.0207170E+02
# Resonance number   74(/  302)   Width number 1
# Resonance number   74(/  302)   Width number 2
# Resonance number   74(/  302)   Width number 3
# Resonance number   74(/  302)   Width number 4
# Resonance number   75(/  302)   Resonance energy  4.0466300E+02
# Resonance number   75(/  302)   Width number 1
# Resonance number   75(/  302)   Width number 2
# Resonance number   75(/  302)   Width number 3
# Resonance number   75(/  302)   Width number 4
# Resonance number   76(/  302)   Resonance energy  4.1280260E+02
# Resonance number   76(/  302)   Width number 1
# Resonance number   76(/  302)   Width number 2
# Resonance number   76(/  302)   Width number 3
# Resonance number   76(/  302)   Width number 4
# Resonance number   77(/  302)   Resonance energy  4.2052410E+02
# Resonance number   77(/  302)   Width number 1
# Resonance number   77(/  302)   Width number 2
# Resonance number   77(/  302)   Width number 3
# Resonance number   77(/  302)   Width number 4
# Resonance number   78(/  302)   Resonance energy  4.2640190E+02
# Resonance number   78(/  302)   Width number 1
# Resonance number   78(/  302)   Width number 2
# Resonance number   78(/  302)   Width number 3
# Resonance number   78(/  302)   Width number 4
# Resonance number   79(/  302)   Resonance energy  4.4299840E+02
# Resonance number   79(/  302)   Width number 1
# Resonance number   79(/  302)   Width number 2
# Resonance number   79(/  302)   Width number 3
# Resonance number   79(/  302)   Width number 4
# Resonance number   80(/  302)   Resonance energy  4.5187990E+02
# Resonance number   80(/  302)   Width number 1
# Resonance number   80(/  302)   Width number 2
# Resonance number   80(/  302)   Width number 3
# Resonance number   80(/  302)   Width number 4
# Resonance number   81(/  302)   Resonance energy  4.5629000E+02
# Resonance number   81(/  302)   Width number 1
# Resonance number   81(/  302)   Width number 2
# Resonance number   81(/  302)   Width number 3
# Resonance number   81(/  302)   Width number 4
# Resonance number   82(/  302)   Resonance energy  4.6865680E+02
# Resonance number   82(/  302)   Width number 1
# Resonance number   82(/  302)   Width number 2
# Resonance number   82(/  302)   Width number 3
# Resonance number   82(/  302)   Width number 4
# Resonance number   83(/  302)   Resonance energy  4.8836890E+02
# Resonance number   83(/  302)   Width number 1
# Resonance number   83(/  302)   Width number 2
# Resonance number   83(/  302)   Width number 3
# Resonance number   83(/  302)   Width number 4
# Resonance number   84(/  302)   Resonance energy  4.9188490E+02
# Resonance number   84(/  302)   Width number 1
# Resonance number   84(/  302)   Width number 2
# Resonance number   84(/  302)   Width number 3
# Resonance number   84(/  302)   Width number 4
# Resonance number   85(/  302)   Resonance energy  5.0111710E+02
# Resonance number   85(/  302)   Width number 1
# Resonance number   85(/  302)   Width number 2
# Resonance number   85(/  302)   Width number 3
# Resonance number   85(/  302)   Width number 4
# Resonance number   86(/  302)   Resonance energy  5.0344060E+02
# Resonance number   86(/  302)   Width number 1
# Resonance number   86(/  302)   Width number 2
# Resonance number   86(/  302)   Width number 3
# Resonance number   86(/  302)   Width number 4
# Resonance number   87(/  302)   Resonance energy  5.1037550E+02
# Resonance number   87(/  302)   Width number 1
# Resonance number   87(/  302)   Width number 2
# Resonance number   87(/  302)   Width number 3
# Resonance number   87(/  302)   Width number 4
# Resonance number   88(/  302)   Resonance energy  5.2085230E+02
# Resonance number   88(/  302)   Width number 1
# Resonance number   88(/  302)   Width number 2
# Resonance number   88(/  302)   Width number 3
# Resonance number   88(/  302)   Width number 4
# Resonance number   89(/  302)   Resonance energy  5.2484970E+02
# Resonance number   89(/  302)   Width number 1
# Resonance number   89(/  302)   Width number 2
# Resonance number   89(/  302)   Width number 3
# Resonance number   89(/  302)   Width number 4
# Resonance number   90(/  302)   Resonance energy  5.2510230E+02
# Resonance number   90(/  302)   Width number 1
# Resonance number   90(/  302)   Width number 2
# Resonance number   90(/  302)   Width number 3
# Resonance number   90(/  302)   Width number 4
# Resonance number   91(/  302)   Resonance energy  5.3118550E+02
# Resonance number   91(/  302)   Width number 1
# Resonance number   91(/  302)   Width number 2
# Resonance number   91(/  302)   Width number 3
# Resonance number   91(/  302)   Width number 4
# Resonance number   92(/  302)   Resonance energy  5.3984030E+02
# Resonance number   92(/  302)   Width number 1
# Resonance number   92(/  302)   Width number 2
# Resonance number   92(/  302)   Width number 3
# Resonance number   92(/  302)   Width number 4
# Resonance number   93(/  302)   Resonance energy  5.4375410E+02
# Resonance number   93(/  302)   Width number 1
# Resonance number   93(/  302)   Width number 2
# Resonance number   93(/  302)   Width number 3
# Resonance number   93(/  302)   Width number 4
# Resonance number   94(/  302)   Resonance energy  5.4640360E+02
# Resonance number   94(/  302)   Width number 1
# Resonance number   94(/  302)   Width number 2
# Resonance number   94(/  302)   Width number 3
# Resonance number   94(/  302)   Width number 4
# Resonance number   95(/  302)   Resonance energy  5.5034410E+02
# Resonance number   95(/  302)   Width number 1
# Resonance number   95(/  302)   Width number 2
# Resonance number   95(/  302)   Width number 3
# Resonance number   95(/  302)   Width number 4
# Resonance number   96(/  302)   Resonance energy  5.5424870E+02
# Resonance number   96(/  302)   Width number 1
# Resonance number   96(/  302)   Width number 2
# Resonance number   96(/  302)   Width number 3
# Resonance number   96(/  302)   Width number 4
# Resonance number   97(/  302)   Resonance energy  5.5487160E+02
# Resonance number   97(/  302)   Width number 1
# Resonance number   97(/  302)   Width number 2
# Resonance number   97(/  302)   Width number 3
# Resonance number   97(/  302)   Width number 4
# Resonance number   98(/  302)   Resonance energy  5.5984310E+02
# Resonance number   98(/  302)   Width number 1
# Resonance number   98(/  302)   Width number 2
# Resonance number   98(/  302)   Width number 3
# Resonance number   98(/  302)   Width number 4
# Resonance number   99(/  302)   Resonance energy  5.6316750E+02
# Resonance number   99(/  302)   Width number 1
# Resonance number   99(/  302)   Width number 2
# Resonance number   99(/  302)   Width number 3
# Resonance number   99(/  302)   Width number 4
# Resonance number  100(/  302)   Resonance energy  5.6356160E+02
# Resonance number  100(/  302)   Width number 1
# Resonance number  100(/  302)   Width number 2
# Resonance number  100(/  302)   Width number 3
# Resonance number  100(/  302)   Width number 4
# Resonance number  101(/  302)   Resonance energy  5.6650090E+02
# Resonance number  101(/  302)   Width number 1
# Resonance number  101(/  302)   Width number 2
# Resonance number  101(/  302)   Width number 3
# Resonance number  101(/  302)   Width number 4
# Resonance number  102(/  302)   Resonance energy  5.7380440E+02
# Resonance number  102(/  302)   Width number 1
# Resonance number  102(/  302)   Width number 2
# Resonance number  102(/  302)   Width number 3
# Resonance number  102(/  302)   Width number 4
# Resonance number  103(/  302)   Resonance energy  5.7468120E+02
# Resonance number  103(/  302)   Width number 1
# Resonance number  103(/  302)   Width number 2
# Resonance number  103(/  302)   Width number 3
# Resonance number  103(/  302)   Width number 4
# Resonance number  104(/  302)   Resonance energy  5.8882980E+02
# Resonance number  104(/  302)   Width number 1
# Resonance number  104(/  302)   Width number 2
# Resonance number  104(/  302)   Width number 3
# Resonance number  104(/  302)   Width number 4
# Resonance number  105(/  302)   Resonance energy  6.0841630E+02
# Resonance number  105(/  302)   Width number 1
# Resonance number  105(/  302)   Width number 2
# Resonance number  105(/  302)   Width number 3
# Resonance number  105(/  302)   Width number 4
# Resonance number  106(/  302)   Resonance energy  6.1004610E+02
# Resonance number  106(/  302)   Width number 1
# Resonance number  106(/  302)   Width number 2
# Resonance number  106(/  302)   Width number 3
# Resonance number  106(/  302)   Width number 4
# Resonance number  107(/  302)   Resonance energy  6.2160270E+02
# Resonance number  107(/  302)   Width number 1
# Resonance number  107(/  302)   Width number 2
# Resonance number  107(/  302)   Width number 3
# Resonance number  107(/  302)   Width number 4
# Resonance number  108(/  302)   Resonance energy  6.3324510E+02
# Resonance number  108(/  302)   Width number 1
# Resonance number  108(/  302)   Width number 2
# Resonance number  108(/  302)   Width number 3
# Resonance number  108(/  302)   Width number 4
# Resonance number  109(/  302)   Resonance energy  6.5870320E+02
# Resonance number  109(/  302)   Width number 1
# Resonance number  109(/  302)   Width number 2
# Resonance number  109(/  302)   Width number 3
# Resonance number  109(/  302)   Width number 4
# Resonance number  110(/  302)   Resonance energy  6.5937260E+02
# Resonance number  110(/  302)   Width number 1
# Resonance number  110(/  302)   Width number 2
# Resonance number  110(/  302)   Width number 3
# Resonance number  110(/  302)   Width number 4
# Resonance number  111(/  302)   Resonance energy  6.8283960E+02
# Resonance number  111(/  302)   Width number 1
# Resonance number  111(/  302)   Width number 2
# Resonance number  111(/  302)   Width number 3
# Resonance number  111(/  302)   Width number 4
# Resonance number  112(/  302)   Resonance energy  6.8456610E+02
# Resonance number  112(/  302)   Width number 1
# Resonance number  112(/  302)   Width number 2
# Resonance number  112(/  302)   Width number 3
# Resonance number  112(/  302)   Width number 4
# Resonance number  113(/  302)   Resonance energy  6.8852710E+02
# Resonance number  113(/  302)   Width number 1
# Resonance number  113(/  302)   Width number 2
# Resonance number  113(/  302)   Width number 3
# Resonance number  113(/  302)   Width number 4
# Resonance number  114(/  302)   Resonance energy  7.3843430E+02
# Resonance number  114(/  302)   Width number 1
# Resonance number  114(/  302)   Width number 2
# Resonance number  114(/  302)   Width number 3
# Resonance number  114(/  302)   Width number 4
# Resonance number  115(/  302)   Resonance energy  7.4464430E+02
# Resonance number  115(/  302)   Width number 1
# Resonance number  115(/  302)   Width number 2
# Resonance number  115(/  302)   Width number 3
# Resonance number  115(/  302)   Width number 4
# Resonance number  116(/  302)   Resonance energy  7.4705740E+02
# Resonance number  116(/  302)   Width number 1
# Resonance number  116(/  302)   Width number 2
# Resonance number  116(/  302)   Width number 3
# Resonance number  116(/  302)   Width number 4
# Resonance number  117(/  302)   Resonance energy  7.5773460E+02
# Resonance number  117(/  302)   Width number 1
# Resonance number  117(/  302)   Width number 2
# Resonance number  117(/  302)   Width number 3
# Resonance number  117(/  302)   Width number 4
# Resonance number  118(/  302)   Resonance energy  7.8180480E+02
# Resonance number  118(/  302)   Width number 1
# Resonance number  118(/  302)   Width number 2
# Resonance number  118(/  302)   Width number 3
# Resonance number  118(/  302)   Width number 4
# Resonance number  119(/  302)   Resonance energy  7.9711940E+02
# Resonance number  119(/  302)   Width number 1
# Resonance number  119(/  302)   Width number 2
# Resonance number  119(/  302)   Width number 3
# Resonance number  119(/  302)   Width number 4
# Resonance number  120(/  302)   Resonance energy  8.0497710E+02
# Resonance number  120(/  302)   Width number 1
# Resonance number  120(/  302)   Width number 2
# Resonance number  120(/  302)   Width number 3
# Resonance number  120(/  302)   Width number 4
# Resonance number  121(/  302)   Resonance energy  8.2978940E+02
# Resonance number  121(/  302)   Width number 1
# Resonance number  121(/  302)   Width number 2
# Resonance number  121(/  302)   Width number 3
# Resonance number  121(/  302)   Width number 4
# Resonance number  122(/  302)   Resonance energy  8.4382490E+02
# Resonance number  122(/  302)   Width number 1
# Resonance number  122(/  302)   Width number 2
# Resonance number  122(/  302)   Width number 3
# Resonance number  122(/  302)   Width number 4
# Resonance number  123(/  302)   Resonance energy  8.5348630E+02
# Resonance number  123(/  302)   Width number 1
# Resonance number  123(/  302)   Width number 2
# Resonance number  123(/  302)   Width number 3
# Resonance number  123(/  302)   Width number 4
# Resonance number  124(/  302)   Resonance energy  8.5815110E+02
# Resonance number  124(/  302)   Width number 1
# Resonance number  124(/  302)   Width number 2
# Resonance number  124(/  302)   Width number 3
# Resonance number  124(/  302)   Width number 4
# Resonance number  125(/  302)   Resonance energy  8.7440730E+02
# Resonance number  125(/  302)   Width number 1
# Resonance number  125(/  302)   Width number 2
# Resonance number  125(/  302)   Width number 3
# Resonance number  125(/  302)   Width number 4
# Resonance number  126(/  302)   Resonance energy  8.7566970E+02
# Resonance number  126(/  302)   Width number 1
# Resonance number  126(/  302)   Width number 2
# Resonance number  126(/  302)   Width number 3
# Resonance number  126(/  302)   Width number 4
# Resonance number  127(/  302)   Resonance energy  8.8554850E+02
# Resonance number  127(/  302)   Width number 1
# Resonance number  127(/  302)   Width number 2
# Resonance number  127(/  302)   Width number 3
# Resonance number  127(/  302)   Width number 4
# Resonance number  128(/  302)   Resonance energy  8.9192430E+02
# Resonance number  128(/  302)   Width number 1
# Resonance number  128(/  302)   Width number 2
# Resonance number  128(/  302)   Width number 3
# Resonance number  128(/  302)   Width number 4
# Resonance number  129(/  302)   Resonance energy  9.0624460E+02
# Resonance number  129(/  302)   Width number 1
# Resonance number  129(/  302)   Width number 2
# Resonance number  129(/  302)   Width number 3
# Resonance number  129(/  302)   Width number 4
# Resonance number  130(/  302)   Resonance energy  9.1288310E+02
# Resonance number  130(/  302)   Width number 1
# Resonance number  130(/  302)   Width number 2
# Resonance number  130(/  302)   Width number 3
# Resonance number  130(/  302)   Width number 4
# Resonance number  131(/  302)   Resonance energy  9.2316200E+02
# Resonance number  131(/  302)   Width number 1
# Resonance number  131(/  302)   Width number 2
# Resonance number  131(/  302)   Width number 3
# Resonance number  131(/  302)   Width number 4
# Resonance number  132(/  302)   Resonance energy  9.3296010E+02
# Resonance number  132(/  302)   Width number 1
# Resonance number  132(/  302)   Width number 2
# Resonance number  132(/  302)   Width number 3
# Resonance number  132(/  302)   Width number 4
# Resonance number  133(/  302)   Resonance energy  9.3766460E+02
# Resonance number  133(/  302)   Width number 1
# Resonance number  133(/  302)   Width number 2
# Resonance number  133(/  302)   Width number 3
# Resonance number  133(/  302)   Width number 4
# Resonance number  134(/  302)   Resonance energy  9.5892940E+02
# Resonance number  134(/  302)   Width number 1
# Resonance number  134(/  302)   Width number 2
# Resonance number  134(/  302)   Width number 3
# Resonance number  134(/  302)   Width number 4
# Resonance number  135(/  302)   Resonance energy  9.6640550E+02
# Resonance number  135(/  302)   Width number 1
# Resonance number  135(/  302)   Width number 2
# Resonance number  135(/  302)   Width number 3
# Resonance number  135(/  302)   Width number 4
# Resonance number  136(/  302)   Resonance energy  9.7215990E+02
# Resonance number  136(/  302)   Width number 1
# Resonance number  136(/  302)   Width number 2
# Resonance number  136(/  302)   Width number 3
# Resonance number  136(/  302)   Width number 4
# Resonance number  137(/  302)   Resonance energy  9.7443750E+02
# Resonance number  137(/  302)   Width number 1
# Resonance number  137(/  302)   Width number 2
# Resonance number  137(/  302)   Width number 3
# Resonance number  137(/  302)   Width number 4
# Resonance number  138(/  302)   Resonance energy  9.8040020E+02
# Resonance number  138(/  302)   Width number 1
# Resonance number  138(/  302)   Width number 2
# Resonance number  138(/  302)   Width number 3
# Resonance number  138(/  302)   Width number 4
# Resonance number  139(/  302)   Resonance energy  9.8540190E+02
# Resonance number  139(/  302)   Width number 1
# Resonance number  139(/  302)   Width number 2
# Resonance number  139(/  302)   Width number 3
# Resonance number  139(/  302)   Width number 4
# Resonance number  140(/  302)   Resonance energy  9.9427810E+02
# Resonance number  140(/  302)   Width number 1
# Resonance number  140(/  302)   Width number 2
# Resonance number  140(/  302)   Width number 3
# Resonance number  140(/  302)   Width number 4
# Resonance number  141(/  302)   Resonance energy  9.9789140E+02
# Resonance number  141(/  302)   Width number 1
# Resonance number  141(/  302)   Width number 2
# Resonance number  141(/  302)   Width number 3
# Resonance number  141(/  302)   Width number 4
# Resonance number  142(/  302)   Resonance energy  9.9868190E+02
# Resonance number  142(/  302)   Width number 1
# Resonance number  142(/  302)   Width number 2
# Resonance number  142(/  302)   Width number 3
# Resonance number  142(/  302)   Width number 4
# Resonance number  143(/  302)   Resonance energy  1.0027920E+03
# Resonance number  143(/  302)   Width number 1
# Resonance number  143(/  302)   Width number 2
# Resonance number  143(/  302)   Width number 3
# Resonance number  143(/  302)   Width number 4
# ...
# Resonance number  248(/  302)   Width number 3
# Resonance number  248(/  302)   Width number 4
# Resonance number  249(/  302)   Resonance energy  1.9969660E+03
# Resonance number  249(/  302)   Width number 1
# Resonance number  249(/  302)   Width number 2
# Resonance number  249(/  302)   Width number 3
# Resonance number  249(/  302)   Width number 4
# Resonance number  250(/  302)   Resonance energy  2.0175030E+03
# Resonance number  250(/  302)   Width number 1
# Resonance number  250(/  302)   Width number 2
# Resonance number  250(/  302)   Width number 3
# Resonance number  250(/  302)   Width number 4
# Resonance number  251(/  302)   Resonance energy  2.0190940E+03
# Resonance number  251(/  302)   Width number 1
# Resonance number  251(/  302)   Width number 2
# Resonance number  251(/  302)   Width number 3
# Resonance number  251(/  302)   Width number 4
# Resonance number  252(/  302)   Resonance energy  2.0784060E+03
# Resonance number  252(/  302)   Width number 1
# Resonance number  252(/  302)   Width number 2
# Resonance number  252(/  302)   Width number 3
# Resonance number  252(/  302)   Width number 4
# Resonance number  253(/  302)   Resonance energy  2.0884710E+03
# Resonance number  253(/  302)   Width number 1
# Resonance number  253(/  302)   Width number 2
# Resonance number  253(/  302)   Width number 3
# Resonance number  253(/  302)   Width number 4
# Resonance number  254(/  302)   Resonance energy  2.0953390E+03
# Resonance number  254(/  302)   Width number 1
# Resonance number  254(/  302)   Width number 2
# Resonance number  254(/  302)   Width number 3
# Resonance number  254(/  302)   Width number 4
# Resonance number  255(/  302)   Resonance energy  2.0983440E+03
# Resonance number  255(/  302)   Width number 1
# Resonance number  255(/  302)   Width number 2
# Resonance number  255(/  302)   Width number 3
# Resonance number  255(/  302)   Width number 4
# Resonance number  256(/  302)   Resonance energy  2.1019820E+03
# Resonance number  256(/  302)   Width number 1
# Resonance number  256(/  302)   Width number 2
# Resonance number  256(/  302)   Width number 3
# Resonance number  256(/  302)   Width number 4
# Resonance number  257(/  302)   Resonance energy  2.1131740E+03
# Resonance number  257(/  302)   Width number 1
# Resonance number  257(/  302)   Width number 2
# Resonance number  257(/  302)   Width number 3
# Resonance number  257(/  302)   Width number 4
# Resonance number  258(/  302)   Resonance energy  2.1267500E+03
# Resonance number  258(/  302)   Width number 1
# Resonance number  258(/  302)   Width number 2
# Resonance number  258(/  302)   Width number 3
# Resonance number  258(/  302)   Width number 4
# Resonance number  259(/  302)   Resonance energy  2.1306110E+03
# Resonance number  259(/  302)   Width number 1
# Resonance number  259(/  302)   Width number 2
# Resonance number  259(/  302)   Width number 3
# Resonance number  259(/  302)   Width number 4
# Resonance number  260(/  302)   Resonance energy  2.1488090E+03
# Resonance number  260(/  302)   Width number 1
# Resonance number  260(/  302)   Width number 2
# Resonance number  260(/  302)   Width number 3
# Resonance number  260(/  302)   Width number 4
# Resonance number  261(/  302)   Resonance energy  2.1518590E+03
# Resonance number  261(/  302)   Width number 1
# Resonance number  261(/  302)   Width number 2
# Resonance number  261(/  302)   Width number 3
# Resonance number  261(/  302)   Width number 4
# Resonance number  262(/  302)   Resonance energy  2.1573400E+03
# Resonance number  262(/  302)   Width number 1
# Resonance number  262(/  302)   Width number 2
# Resonance number  262(/  302)   Width number 3
# Resonance number  262(/  302)   Width number 4
# Resonance number  263(/  302)   Resonance energy  2.1648150E+03
# Resonance number  263(/  302)   Width number 1
# Resonance number  263(/  302)   Width number 2
# Resonance number  263(/  302)   Width number 3
# Resonance number  263(/  302)   Width number 4
# Resonance number  264(/  302)   Resonance energy  2.1941150E+03
# Resonance number  264(/  302)   Width number 1
# Resonance number  264(/  302)   Width number 2
# Resonance number  264(/  302)   Width number 3
# Resonance number  264(/  302)   Width number 4
# Resonance number  265(/  302)   Resonance energy  2.2134510E+03
# Resonance number  265(/  302)   Width number 1
# Resonance number  265(/  302)   Width number 2
# Resonance number  265(/  302)   Width number 3
# Resonance number  265(/  302)   Width number 4
# Resonance number  266(/  302)   Resonance energy  2.2235370E+03
# Resonance number  266(/  302)   Width number 1
# Resonance number  266(/  302)   Width number 2
# Resonance number  266(/  302)   Width number 3
# Resonance number  266(/  302)   Width number 4
# Resonance number  267(/  302)   Resonance energy  2.2285070E+03
# Resonance number  267(/  302)   Width number 1
# Resonance number  267(/  302)   Width number 2
# Resonance number  267(/  302)   Width number 3
# Resonance number  267(/  302)   Width number 4
# Resonance number  268(/  302)   Resonance energy  2.2417530E+03
# Resonance number  268(/  302)   Width number 1
# Resonance number  268(/  302)   Width number 2
# Resonance number  268(/  302)   Width number 3
# Resonance number  268(/  302)   Width number 4
# Resonance number  269(/  302)   Resonance energy  2.2446020E+03
# Resonance number  269(/  302)   Width number 1
# Resonance number  269(/  302)   Width number 2
# Resonance number  269(/  302)   Width number 3
# Resonance number  269(/  302)   Width number 4
# Resonance number  270(/  302)   Resonance energy  2.2531590E+03
# Resonance number  270(/  302)   Width number 1
# Resonance number  270(/  302)   Width number 2
# Resonance number  270(/  302)   Width number 3
# Resonance number  270(/  302)   Width number 4
# Resonance number  271(/  302)   Resonance energy  2.2598540E+03
# Resonance number  271(/  302)   Width number 1
# Resonance number  271(/  302)   Width number 2
# Resonance number  271(/  302)   Width number 3
# Resonance number  271(/  302)   Width number 4
# Resonance number  272(/  302)   Resonance energy  2.2700790E+03
# Resonance number  272(/  302)   Width number 1
# Resonance number  272(/  302)   Width number 2
# Resonance number  272(/  302)   Width number 3
# Resonance number  272(/  302)   Width number 4
# Resonance number  273(/  302)   Resonance energy  2.2880720E+03
# Resonance number  273(/  302)   Width number 1
# Resonance number  273(/  302)   Width number 2
# Resonance number  273(/  302)   Width number 3
# Resonance number  273(/  302)   Width number 4
# Resonance number  274(/  302)   Resonance energy  2.2892140E+03
# Resonance number  274(/  302)   Width number 1
# Resonance number  274(/  302)   Width number 2
# Resonance number  274(/  302)   Width number 3
# Resonance number  274(/  302)   Width number 4
# Resonance number  275(/  302)   Resonance energy  2.2973600E+03
# Resonance number  275(/  302)   Width number 1
# Resonance number  275(/  302)   Width number 2
# Resonance number  275(/  302)   Width number 3
# Resonance number  275(/  302)   Width number 4
# Resonance number  276(/  302)   Resonance energy  2.3040440E+03
# Resonance number  276(/  302)   Width number 1
# Resonance number  276(/  302)   Width number 2
# Resonance number  276(/  302)   Width number 3
# Resonance number  276(/  302)   Width number 4
# Resonance number  277(/  302)   Resonance energy  2.3111820E+03
# Resonance number  277(/  302)   Width number 1
# Resonance number  277(/  302)   Width number 2
# Resonance number  277(/  302)   Width number 3
# Resonance number  277(/  302)   Width number 4
# Resonance number  278(/  302)   Resonance energy  2.3187280E+03
# Resonance number  278(/  302)   Width number 1
# Resonance number  278(/  302)   Width number 2
# Resonance number  278(/  302)   Width number 3
# Resonance number  278(/  302)   Width number 4
# Resonance number  279(/  302)   Resonance energy  2.3309950E+03
# Resonance number  279(/  302)   Width number 1
# Resonance number  279(/  302)   Width number 2
# Resonance number  279(/  302)   Width number 3
# Resonance number  279(/  302)   Width number 4
# Resonance number  280(/  302)   Resonance energy  2.3336530E+03
# Resonance number  280(/  302)   Width number 1
# Resonance number  280(/  302)   Width number 2
# Resonance number  280(/  302)   Width number 3
# Resonance number  280(/  302)   Width number 4
# Resonance number  281(/  302)   Resonance energy  2.3384430E+03
# Resonance number  281(/  302)   Width number 1
# Resonance number  281(/  302)   Width number 2
# Resonance number  281(/  302)   Width number 3
# Resonance number  281(/  302)   Width number 4
# Resonance number  282(/  302)   Resonance energy  2.3448810E+03
# Resonance number  282(/  302)   Width number 1
# Resonance number  282(/  302)   Width number 2
# Resonance number  282(/  302)   Width number 3
# Resonance number  282(/  302)   Width number 4
# Resonance number  283(/  302)   Resonance energy  2.3473940E+03
# Resonance number  283(/  302)   Width number 1
# Resonance number  283(/  302)   Width number 2
# Resonance number  283(/  302)   Width number 3
# Resonance number  283(/  302)   Width number 4
# Resonance number  284(/  302)   Resonance energy  2.3632880E+03
# Resonance number  284(/  302)   Width number 1
# Resonance number  284(/  302)   Width number 2
# Resonance number  284(/  302)   Width number 3
# Resonance number  284(/  302)   Width number 4
# Resonance number  285(/  302)   Resonance energy  2.3659130E+03
# Resonance number  285(/  302)   Width number 1
# Resonance number  285(/  302)   Width number 2
# Resonance number  285(/  302)   Width number 3
# Resonance number  285(/  302)   Width number 4
# Resonance number  286(/  302)   Resonance energy  2.3755920E+03
# Resonance number  286(/  302)   Width number 1
# Resonance number  286(/  302)   Width number 2
# Resonance number  286(/  302)   Width number 3
# Resonance number  286(/  302)   Width number 4
# Resonance number  287(/  302)   Resonance energy  2.3787910E+03
# Resonance number  287(/  302)   Width number 1
# Resonance number  287(/  302)   Width number 2
# Resonance number  287(/  302)   Width number 3
# Resonance number  287(/  302)   Width number 4
# Resonance number  288(/  302)   Resonance energy  2.3840160E+03
# Resonance number  288(/  302)   Width number 1
# Resonance number  288(/  302)   Width number 2
# Resonance number  288(/  302)   Width number 3
# Resonance number  288(/  302)   Width number 4
# Resonance number  289(/  302)   Resonance energy  2.3967110E+03
# Resonance number  289(/  302)   Width number 1
# Resonance number  289(/  302)   Width number 2
# Resonance number  289(/  302)   Width number 3
# Resonance number  289(/  302)   Width number 4
# Resonance number  290(/  302)   Resonance energy  2.4053770E+03
# Resonance number  290(/  302)   Width number 1
# Resonance number  290(/  302)   Width number 2
# Resonance number  290(/  302)   Width number 3
# Resonance number  290(/  302)   Width number 4
# Resonance number  291(/  302)   Resonance energy  2.4097980E+03
# Resonance number  291(/  302)   Width number 1
# Resonance number  291(/  302)   Width number 2
# Resonance number  291(/  302)   Width number 3
# Resonance number  291(/  302)   Width number 4
# Resonance number  292(/  302)   Resonance energy  2.4116070E+03
# Resonance number  292(/  302)   Width number 1
# Resonance number  292(/  302)   Width number 2
# Resonance number  292(/  302)   Width number 3
# Resonance number  292(/  302)   Width number 4
# Resonance number  293(/  302)   Resonance energy  2.4165450E+03
# Resonance number  293(/  302)   Width number 1
# Resonance number  293(/  302)   Width number 2
# Resonance number  293(/  302)   Width number 3
# Resonance number  293(/  302)   Width number 4
# Resonance number  294(/  302)   Resonance energy  2.4233090E+03
# Resonance number  294(/  302)   Width number 1
# Resonance number  294(/  302)   Width number 2
# Resonance number  294(/  302)   Width number 3
# Resonance number  294(/  302)   Width number 4
# Resonance number  295(/  302)   Resonance energy  2.4290610E+03
# Resonance number  295(/  302)   Width number 1
# Resonance number  295(/  302)   Width number 2
# Resonance number  295(/  302)   Width number 3
# Resonance number  295(/  302)   Width number 4
# Resonance number  296(/  302)   Resonance energy  2.4397570E+03
# Resonance number  296(/  302)   Width number 1
# Resonance number  296(/  302)   Width number 2
# Resonance number  296(/  302)   Width number 3
# Resonance number  296(/  302)   Width number 4
# Resonance number  297(/  302)   Resonance energy  2.4422390E+03
# Resonance number  297(/  302)   Width number 1
# Resonance number  297(/  302)   Width number 2
# Resonance number  297(/  302)   Width number 3
# Resonance number  297(/  302)   Width number 4
# Resonance number  298(/  302)   Resonance energy  2.4469710E+03
# Resonance number  298(/  302)   Width number 1
# Resonance number  298(/  302)   Width number 2
# Resonance number  298(/  302)   Width number 3
# Resonance number  298(/  302)   Width number 4
# Resonance number  299(/  302)   Resonance energy  2.4508490E+03
# Resonance number  299(/  302)   Width number 1
# Resonance number  299(/  302)   Width number 2
# Resonance number  299(/  302)   Width number 3
# Resonance number  299(/  302)   Width number 4
# Resonance number  300(/  302)   Resonance energy  2.4626430E+03
# Resonance number  300(/  302)   Width number 1
# Resonance number  300(/  302)   Width number 2
# Resonance number  300(/  302)   Width number 3
# Resonance number  300(/  302)   Width number 4
# Resonance number  301(/  302)   Resonance energy  2.4696240E+03
# Resonance number  301(/  302)   Width number 1
# Resonance number  301(/  302)   Width number 2
# Resonance number  301(/  302)   Width number 3
# Resonance number  301(/  302)   Width number 4
# Resonance number  302(/  302)   Resonance energy  2.4773800E+03
# Resonance number  302(/  302)   Width number 1
# Resonance number  302(/  302)   Width number 2
# Resonance number  302(/  302)   Width number 3
# Resonance number  302(/  302)   Width number 4
#
#  ---message from rpxlc12---resonance parameter loop done                309.1s
#
#  ---message from rpxlc12---sensitivity calculation continues            309.9s
#
#  ---message from rpxlc12---sensitivity calculation completed            311.4s
#
#  errorr...                                                              311.4s
#
#  processing mat  9437
#  ---------------------
#   94-Pu-239 LANL       EVAL-DEC17             LANL, ORNL, et al.
#
#  covariances calculated for  2 reactions and   89 groups                311.5s
#
#  errorr...                                                              311.5s
#
#  ---message from errorr---mf35 processing with the mf5 spectrum vector
#
#  processing mat  9437
#  ---------------------
#   94-Pu-239 LANL       EVAL-DEC17             LANL, ORNL, et al.
#
#  ---message from sumchk---zero-sum test failed
#                           applying normalization correction
#
#  ---message from covbin---converting mf35 convariance data to errorj format
#
#  ---message from sumchk---zero-sum test passed
#
#  ---message from covbin---converting mf35 convariance data to errorj format
#
#  ---message from sumchk---zero-sum test passed
#
#  ---message from covbin---converting mf35 convariance data to errorj format
#
#  ---message from sumchk---zero-sum test passed
#
#  ---message from covbin---converting mf35 convariance data to errorj format
#
#  covariances calculated for  1 reactions and  621 groups                312.0s
#
#  errorr...                                                              312.1s
#
#  ---message from grpav4---collapsing NGOUT mf=3, mt=251 to the union grid
#
#  legendre group averaging completed                                     312.1s
#
#
#  processing mat  9437
#  ---------------------
#   94-Pu-239 LANL       EVAL-DEC17             LANL, ORNL, et al.
#
#  covariances calculated for  1 reactions and   76 groups                312.1s
#                                                                         312.1s
#  *****************************************************************************
# The shape of the retrieved covariance data is: 44 by 44
# The covariance plot's filename is: covariancePlot_45Groups_Pu239MT18_Relative.png
# The CSV's filename is: covarianceMatrix_45Groups_Pu239_MT_18_Relative.csv
# Covariance Retrieval Process Complete

# %% [markdown]
# With this covariance matrix, we can now generate our random sampling ACE files.

# %%
WINDIGO.generate_random_sampling_ace_files(
    frendy_Path = "/mnt/c/Users/jacob/frendy_20241030",
    unperturbed_ACE_file_path = unperturbed_pu239_path,
    relative_covariance_matrix_path=(
        pu239_fission_relative_covariance_data_path
    ),
    energy_grid=scale44_grid_MeV,
    mt_Number=18,
    nuclide="Pu239",
    sample_size=100,
    cleanup_Flag=True,
)
# Out:
# Perturbation factors created successfully
# Intermediate Files Removed
# All ACE files generated successfully and are located in: /mnt/c/Users/jacob/frendy_20241030/Pu239_RandomSamplingACEFiles_ReactionMT_18
# '/mnt/c/Users/jacob/frendy_20241030/Pu239_RandomSamplingACEFiles_ReactionMT_18'

# %% [markdown]
# We now have all of the perturbed ACE files that we will need to perform our uncertainty quantification analysis.
